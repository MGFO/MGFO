# %% [markdown]
# ## Ejemplo de Aplicación con la red IEEE 13 modificada ##

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import math

# %%
import pandapower as pp

# %%
import pandas as pd

# %%
import pyomo.environ as pe

# %%
import matplotlib.pyplot as plt

# %%
import ModelWriters as mw

# %%
import ModelWriters.Scenes as Scenes

# %%
import ModelWriters.Resources as Resources

# %%
import ModelWriters.Simulation as Simulation

# %% [markdown]
# Creating Network

# %%
net = pp.create_empty_network()

# %% [markdown]
# Adding line parameter data:

# %%
line_data = {"c_nf_per_km": 0, "r_ohm_per_km": 0.40, "x_ohm_per_km": 0.30, "max_i_ka": 0.300, "type": "al", "q_mm2": 95, "alpha": 4.03e-3}
pp.create_std_type(net, line_data, "AlAc 95", element='line')

line_data = {"c_nf_per_km": 0, "r_ohm_per_km": 0.50, "x_ohm_per_km": 0.35, "max_i_ka": 0.250, "type": "al", "q_mm2": 70, "alpha": 4.03e-3}
pp.create_std_type(net, line_data, "AlAc 70", element='line')

line_data = {"c_nf_per_km": 0, "r_ohm_per_km": 0.70, "x_ohm_per_km": 0.40, "max_i_ka": 0.190, "type": "al", "q_mm2": 50, "alpha": 4.03e-3}
pp.create_std_type(net, line_data, "AlAc 50", element='line')

line_data = {"c_nf_per_km": 0, "r_ohm_per_km": 1.20, "x_ohm_per_km": 0.45, "max_i_ka": 0.130, "type": "al", "q_mm2": 25, "alpha": 4.03e-3}
pp.create_std_type(net, line_data, "AlAc 25", element='line')

# %%
b650 = pp.create_bus(net, name='650', vn_kv=13.2) 

pp.create_ext_grid(net, name='Ext Grid', bus=b650)

b632 = pp.create_bus(net, name='632', vn_kv=13.2) 
b633 = pp.create_bus(net, name='633', vn_kv=13.2) 
b645 = pp.create_bus(net, name='645', vn_kv=13.2) 
b646 = pp.create_bus(net, name='646', vn_kv=13.2) 

b671 = pp.create_bus(net, name='671', vn_kv=13.2)  
b675 = pp.create_bus(net, name='675', vn_kv=13.2) 

b611 = pp.create_bus(net, name='611', vn_kv=13.2) 
b684 = pp.create_bus(net, name='684', vn_kv=13.2) 
b652 = pp.create_bus(net, name='652', vn_kv=13.2) 

pp.create_line(net, name='L 650-632', from_bus=b650, to_bus=b632, length_km=2.0, std_type="AlAc 95") 
pp.create_line(net, name='L 632-671', from_bus=b632, to_bus=b671, length_km=2.0, std_type="AlAc 95") 
pp.create_line(net, name='L 671-684', from_bus=b671, to_bus=b684, length_km=1.5, std_type="AlAc 70") 

pp.create_line(net, name='L 632-645', from_bus=b632, to_bus=b645, length_km=0.5, std_type="AlAc 50") 
pp.create_line(net, name='L 645-646', from_bus=b645, to_bus=b646, length_km=0.5, std_type="AlAc 50") 
pp.create_line(net, name='L 632-633', from_bus=b632, to_bus=b633, length_km=1.0, std_type="AlAc 50") 
pp.create_line(net, name='L 671-675', from_bus=b671, to_bus=b675, length_km=1.0, std_type="AlAc 50") 
pp.create_line(net, name='L 684-611', from_bus=b684, to_bus=b611, length_km=0.5, std_type="AlAc 25") 
pp.create_line(net, name='L 684-652', from_bus=b684, to_bus=b652, length_km=1.0, std_type="AlAc 25") 

pp.create_load(net, bus=b645, p_mw=1.20, q_mvar = 0.58)
pp.create_load(net, bus=b646, p_mw=1.50, q_mvar = 0.58*1.5/1.2)
pp.create_load(net, bus=b633, p_mw=0.80, q_mvar = math.sqrt((0.80/0.85)**2-0.8**2))
pp.create_load(net, bus=b675, p_mw=0.90, q_mvar = math.sqrt((0.90/0.85)**2-0.9**2))
pp.create_load(net, bus=b611, p_mw=0.50, q_mvar = math.sqrt((0.50/0.80)**2-0.5**2))
pp.create_load(net, bus=b652, p_mw=0.60, q_mvar = math.sqrt((0.60/0.80)**2-0.6**2))


pp.create_sgen(net, name='PV 633', bus=b633, p_mw=0.00, q_mvar=0.00, max_p_mw=0.00, max_q_mvar=0.00)

pp.create_sgen(net, name='WT 633', bus=b633, p_mw=0.00, q_mvar=0.00, max_p_mw=0.00, max_q_mvar=0.00)
# Out:
# 1

# %%
net.bus
# Out:
#   name  vn_kv type  zone  in_service
# 0  650   13.2    b  None        True
# 1  632   13.2    b  None        True
# 2  633   13.2    b  None        True
# 3  645   13.2    b  None        True
# 4  646   13.2    b  None        True
# 5  671   13.2    b  None        True
# 6  675   13.2    b  None        True
# 7  611   13.2    b  None        True
# 8  684   13.2    b  None        True
# 9  652   13.2    b  None        True

# %%
net.ext_grid
# Out:
#        name  bus  vm_pu  va_degree  in_service
# 0  Ext Grid    0    1.0        0.0        True

# %%
net.sgen
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar
# 0            True       0.0         0.0
# 1            True       0.0         0.0

# %%
net.load
# Out:
#    name  bus  p_mw    q_mvar  const_z_percent  const_i_percent  sn_mva  \
# 0  None    3   1.2  0.580000              0.0              0.0     NaN
# 1  None    4   1.5  0.725000              0.0              0.0     NaN
# 2  None    2   0.8  0.495795              0.0              0.0     NaN
# 3  None    6   0.9  0.557770              0.0              0.0     NaN
# 4  None    7   0.5  0.375000              0.0              0.0     NaN
# 5  None    9   0.6  0.450000              0.0              0.0     NaN
#
#    scaling  in_service type
# 0      1.0        True  wye
# 1      1.0        True  wye
# 2      1.0        True  wye
# 3      1.0        True  wye
# 4      1.0        True  wye
# 5      1.0        True  wye

# %%
net.storage
# Out:
# Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type]
# Index: []

# %%
 pp.runpp(net)

# %%
net.res_bus
# Out:
#       vm_pu  va_degree      p_mw    q_mvar
# 0  1.000000   0.000000 -5.787786 -3.390437
# 1  0.961761  -0.259960  0.000000  0.000000
# 2  0.957214  -0.250296  0.800000  0.495795
# 3  0.954492  -0.289781  1.200000  0.580000
# 4  0.950446  -0.306545  1.500000  0.725000
# 5  0.946893  -0.294868  0.000000  0.000000
# 6  0.941694  -0.283643  0.900000  0.557770
# 7  0.936815  -0.238107  0.500000  0.375000
# 8  0.939170  -0.280154  0.000000  0.000000
# 9  0.933497  -0.178884  0.600000  0.450000

# %%
net.res_line
# Out:
#    p_from_mw  q_from_mvar   p_to_mw  q_to_mvar     pl_mw   ql_mvar  i_from_ka  \
# 0   5.787786     3.390437 -5.581204  -3.235501  0.206582  0.154936   0.293387
# 1   2.051226     1.417575 -2.020366  -1.394430  0.030860  0.023145   0.113394
# 2   1.115287     0.833758 -1.105978  -0.827242  0.009309  0.006516   0.064321
# 3   2.726094     1.319911 -2.706172  -1.308527  0.019922  0.011384   0.137744
# 4   1.506172     0.728527 -1.500000  -0.725000  0.006172  0.003527   0.076669
# 5   0.803884     0.498015 -0.800000  -0.495795  0.003884  0.002219   0.043006
# 6   0.905079     0.560672 -0.900000  -0.557770  0.005079  0.002902   0.049179
# 7   0.501533     0.375575 -0.500000  -0.375000  0.001533  0.000575   0.029180
# 8   0.604446     0.451667 -0.600000  -0.450000  0.004446  0.001667   0.035141
#
#     i_to_ka      i_ka  vm_from_pu  va_from_degree  vm_to_pu  va_to_degree  \
# 0  0.293387  0.293387    1.000000        0.000000  0.961761     -0.259960
# 1  0.113394  0.113394    0.961761       -0.259960  0.946893     -0.294868
# 2  0.064321  0.064321    0.946893       -0.294868  0.939170     -0.280154
# 3  0.137744  0.137744    0.961761       -0.259960  0.954492     -0.289781
# 4  0.076669  0.076669    0.954492       -0.289781  0.950446     -0.306545
# 5  0.043006  0.043006    0.961761       -0.259960  0.957214     -0.250296
# 6  0.049179  0.049179    0.946893       -0.294868  0.941694     -0.283643
# 7  0.029180  0.029180    0.939170       -0.280154  0.936815     -0.238107
# 8  0.035141  0.035141    0.939170       -0.280154  0.933497     -0.178884
#
#    loading_percent
# 0        97.795574
# 1        37.798022
# 2        25.728549
# 3        72.496695
# 4        40.351960
# 5        22.634647
# 6        25.883659
# 7        22.446475
# 8        27.031511

# %%
print(net)
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (10 elements)
#    - load (6 elements)
#    - sgen (2 elements)
#    - ext_grid (1 element)
#    - line (9 elements)
#  and the following results tables:
#    - res_bus (10 elements)
#    - res_line (9 elements)
#    - res_ext_grid (1 element)
#    - res_load (6 elements)
#    - res_sgen (2 elements)

# %% [markdown]
# ## Construcción de Escenarios

# %%
Mean_Monthly_Solar_Irradiance = [7.5e3, 7.2e3, 6.5e3, 5.5e3, 4.5e3, 3.5e3, 2.5e3, 3.5e3, 4.5e3, 6.0e3, 7.0e3, 8.5e3]

# %%
sun_synth = Simulation.MonthlySolarIrradianceSimulator(latitude = -40.5490, longitude = -62.2438, 
                                                       monthly_average_irradiation = Mean_Monthly_Solar_Irradiance)

# %%
wind_synth = Simulation.Weibull(c = 7.5 / 0.886, k = 2)

# %%
wind_synth = Simulation.CorrelatedWeibull(c = 7.5 / 0.886, k = 2)

# %%
#s = Scenes.SceneBuilder(years = 4, subperiods = 1, days_in_subperiods = 1, dt=24, growth_rate = 0.025, discount_rate = 0.05)
#s = Scenes.SceneBuilder(years = 4, subperiods = 4, days_in_subperiods = 1, dt=1, growth_rate = 0.025, discount_rate = 0.05)
#s = Scenes.SceneBuilder(years = 20, subperiods = 4, days_in_subperiods = 5, dt=2, growth_rate = 0.025, discount_rate = 0.03)
#s = Scenes.SceneBuilder(years = 20, subperiods = 12, days_in_subperiods = 7, growth_rate = 0.025, discount_rate = 0.03)
#s = Scenes.SceneBuilder(years = 20, subperiods = 1, days_in_subperiods = 365, dt = 1, growth_rate = 0.025, discount_rate = 0.03)
s = Scenes.SceneBuilder(years = 20, subperiods = 6, days_in_subperiods = 1, dt = 3, growth_rate = 0.025, discount_rate = 0.10)
s.additional_columns['solar_irradiance'] = sun_synth
s.additional_columns['wind_speed'] = wind_synth
scenes = s.build_scenes()
scenes
# Out:
#      year    day         dd  hour   dt   growth  discount  solar_irradiance  \
# 0     0.0    0.0  60.833333   0.0  3.0  1.00000  1.000000      0.000000e+00
# 1     0.0    0.0  60.833333   3.0  3.0  1.00000  1.000000      0.000000e+00
# 2     0.0    0.0  60.833333   6.0  3.0  1.00000  1.000000      1.227576e+02
# 3     0.0    0.0  60.833333   9.0  3.0  1.00000  1.000000      4.352726e+02
# 4     0.0    0.0  60.833333  12.0  3.0  1.00000  1.000000      6.198269e+02
# ..    ...    ...        ...   ...  ...      ...       ...               ...
# 955  19.0  300.0  60.833333   9.0  3.0  1.59865  0.163508      6.984522e+02
# 956  19.0  300.0  60.833333  12.0  3.0  1.59865  0.163508      9.587094e+02
# 957  19.0  300.0  60.833333  15.0  3.0  1.59865  0.163508      7.781696e+02
# 958  19.0  300.0  60.833333  18.0  3.0  1.59865  0.163508      1.378149e-13
# 959  19.0  300.0  60.833333  21.0  3.0  1.59865  0.163508      0.000000e+00
#
#      wind_speed
# 0      1.320183
# 1      2.189322
# 2      2.945433
# 3      3.729337
# 4      6.369736
# ..          ...
# 955    8.752587
# 956    7.900571
# 957    7.411754
# 958    7.714469
# 959    6.613541
#
# [960 rows x 9 columns]

# %% [markdown]
# An scene set with variying discount rate

# %%
scenery_collection = {}
for i in range(1, 11):
    s = Scenes.SceneBuilder(years = 20, subperiods = 6, days_in_subperiods = 2, dt = 1, growth_rate = 0.025, discount_rate = i/100)
    s.additional_columns['solar_irradiance'] = sun_synth
    s.additional_columns['wind_speed'] = wind_synth
    scenes = s.build_scenes()
    scenery_collection[i] = scenes

# %%
scenery_collection[1]
# Out:
#       year    day         dd  hour   dt   growth  discount  solar_irradiance  \
# 0      0.0    0.0  30.416667   0.0  1.0  1.00000   1.00000               0.0
# 1      0.0    0.0  30.416667   1.0  1.0  1.00000   1.00000               0.0
# 2      0.0    0.0  30.416667   2.0  1.0  1.00000   1.00000               0.0
# 3      0.0    0.0  30.416667   3.0  1.0  1.00000   1.00000               0.0
# 4      0.0    0.0  30.416667   4.0  1.0  1.00000   1.00000               0.0
# ...    ...    ...        ...   ...  ...      ...       ...               ...
# 5755  19.0  301.0  30.416667  19.0  1.0  1.59865   0.82774               0.0
# 5756  19.0  301.0  30.416667  20.0  1.0  1.59865   0.82774               0.0
# 5757  19.0  301.0  30.416667  21.0  1.0  1.59865   0.82774               0.0
# 5758  19.0  301.0  30.416667  22.0  1.0  1.59865   0.82774               0.0
# 5759  19.0  301.0  30.416667  23.0  1.0  1.59865   0.82774               0.0
#
#       wind_speed
# 0       5.604364
# 1       5.596266
# 2       5.988096
# 3       6.879014
# 4       7.287946
# ...          ...
# 5755    7.196743
# 5756    7.471584
# 5757    6.173207
# 5758    7.620135
# 5759    6.420266
#
# [5760 rows x 9 columns]

# %% [markdown]
# ## External Data Loading

# %% [markdown]
# ### Residential User, summer and winter cases

# %%
residential_user_summer = pd.read_csv('.\\Data\\UserResSum.csv', header = None, squeeze = True)

# %%
residential_user_winter = pd.read_csv('.\\Data\\UserResWin.csv', header = None, squeeze = True)

# %% [markdown]
# Data is loaded to a data syntethizer:

# %%
Residential_Synth = Simulation.DailyInterpolator( post_random_up=0.15, post_random_down=0.15)

#data is hourly, 24 hs
hours = [h for h in range(24)]

Residential_Synth.add_day(355, hours, residential_user_summer)   
Residential_Synth.add_day(172, hours, residential_user_winter)

# %% [markdown]
# ### Commercial User, summer and winter cases

# %%
commercial_user_summer = pd.read_csv('.\\Data\\UserComSum.csv', header = None, squeeze = True)

# %%
commercial_user_winter = pd.read_csv('.\\Data\\UserComWin.csv', header = None, squeeze = True)

# %% [markdown]
# Data is loaded to a data syntethizer:

# %%
Commercial_Synth = Simulation.DailyInterpolator( post_random_up=0.15, post_random_down=0.15)
Commercial_Synth.add_day(355, hours, commercial_user_summer)   #north hemisfere convention, summer is June 21st
Commercial_Synth.add_day(172, hours, commercial_user_winter)   #north hemisfere convention, summer is June 21st

# %% [markdown]
# ### Industrial User, summer and winter cases

# %%
industrial_user_summer = pd.read_csv('.\\Data\\UserIndSum.csv', header = None, squeeze = True)

# %%
industrial_user_winter = pd.read_csv('.\\Data\\UserIndWin.csv', header = None, squeeze = True)

# %% [markdown]
# Data is loaded to a data syntethizer:

# %%
Industrial_Synth = Simulation.DailyInterpolator( post_random_up=0.05, post_random_down=0.05)
Industrial_Synth.add_day(355, hours, industrial_user_summer)   #north hemisfere convention, summer is June 21st
Industrial_Synth.add_day(172, hours, industrial_user_winter)   #north hemisfere convention, summer is June 21st

# %% [markdown]
# Example using Residential User:

# %%
res = [Residential_Synth.simulate(scenes.iloc[i]) for i in range(len(scenes))]

# %%
fig, ax = plt.subplots(1, 1)

fig.set_size_inches(10,6)
    
ax.plot(res[240:480])
    
ax.set_xlabel('scene')
ax.set_ylabel('P[pu]')

ax.legend()

ax.grid(True)


plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
def plot_results(results, a = 0, b = 240, items = None, elements = False, lines = False, l_ep = False):
    # Set the plot curve with markers and a title
    if not (elements or lines or l_ep or items):
        raise Exception("Nothing to plot")
    
    fig, ax = plt.subplots(1, 1)

    fig.set_size_inches(10,6)
    
    for col in results:
        p = False
        if items and col in items:
            p = True
        elif col[0:2] == 'L ':
            if col[-4:] == 'ep_h':
                if l_ep:
                    p = True
            elif lines:
                p = True
        elif elements:
            p = True

        if p:
            ax.plot(results[col][a:b], label = col)
    
    ax.set_xlabel('time')
    ax.set_ylabel('P[mw]')

    ax.legend()

    ax.grid(True)


    plt.show()

# %% [markdown]
# # LCOE without DG.

# %% [markdown]
# ## Optimization models

# %%
mw.network_precondition(net)

# %%
net.ext_grid['model'][0] = Resources.ExtGrid('SET', pr_mw = 10.0, peak_value=150, valley_value=80, rest_value=100)

# %%
net.load['model'][0] = Resources.Load('645', pr_mw = 1.20, pa_pu = Industrial_Synth)
net.load['model'][1] = Resources.Load('646', pr_mw = 1.50, pa_pu = Industrial_Synth)
net.load['model'][2] = Resources.Load('633', pr_mw = 0.80, pa_pu = Commercial_Synth)
net.load['model'][3] = Resources.Load('675', pr_mw = 0.90, pa_pu = Commercial_Synth)
net.load['model'][4] = Resources.Load('611', pr_mw = 0.50, pa_pu = Residential_Synth)
net.load['model'][5] = Resources.Load('652', pr_mw = 0.60, pa_pu = Residential_Synth)

# %%
net.sgen['model'][0] = Resources.PVGenerator('PV 633', ic_0_mu = 10.0e3, ic_1_mu = 1.35e6, oc_0_mu = 15.0e3/8760, oc_1_mu = 0.0)

net.sgen['model'][1] = Resources.WTGeneratorDiscrete('WT 633', ic_0_mu = 10.0e3, unit_size_mw = 0.800, unit_cost_mu = 1200e3, oc_0_mu = 0.00,
                                                     oc_1_mu = 15.0, cut_in = 3.0, v_rated = 12.0, cut_out = 34.0)   #Enercom E-53 800 kW

# %%
net.sgen
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True       0.0         0.0  Resource: PV 633
# 1            True       0.0         0.0  Resource: WT 633

# %%
net.storage
# Out:
# Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: []

# %% [markdown]
# # LCOE without DERs

# %% [markdown]
# ## Model Creation

# %%
#model_writer = mw.MultiBusbarModelWriter(net, scenes, overload_cost = 2.0)
#model_writer = mw.MultiBusbarModelWriter(net, scenes, overload_cost = None)
#model_writer = mw.MultiBusbarModelWriter(net, scenes, overload_hours = 4000)
def eval_scene(subperiods, days_in_subperiods, dt):
    res = {}
    
    s = Scenes.SceneBuilder(years = 20, subperiods = subperiods, days_in_subperiods = days_in_subperiods, dt = dt, growth_rate = 0.025, discount_rate = 0.07)
    s.additional_columns['solar_irradiance'] = sun_synth
    s.additional_columns['wind_speed'] = wind_synth
    scenes = s.build_scenes()
    scenery_collection[i] = scenes
    
    der_elements = [net.sgen['model'][0], net.sgen['model'][1]]
    ext_elements = [net.ext_grid['model'][0]]
    
    print("Evaluando: {0}-{1}-{2}".format(subperiods, days_in_subperiods, dt))
    print('Creando Modelo')
    model_writer = mw.MultiBusbarModelWriter(net, scenes, overload_cost = None, overload_hours = None, max_i_pu = 1.2)
    model = model_writer.create_model()
    #additional constraints
    ##model_writer.additional_constraint("no_PV", net.sgen['model'][0].create + net.sgen['model'][1].create + net.sgen['model'][2].create == 0)
    ##model_writer.additional_constraint("no_ST", net.storage['model'][0].create + net.storage['model'][1].create  == 0)
    ##model_writer.additional_constraint("no_WT", net.sgen['model'][3].create == 0)
    #resolution
    print('Resolviendo')
    opt = pe.SolverFactory('cplex')
    result_obj= opt.solve(model, tee=True)
    print('Guardando Resultados')
    model_writer.backconfigure_network()
    
    res['sgen'] = net.sgen.copy(deep = True)
    res['storage'] = net.storage.copy(deep = True)
    
    ic = pe.value(model_writer.initial_cost_expression())
    oc_e = model_writer.opetaring_costs_value(ext_elements)
    oc_der = model_writer.opetaring_costs_value(der_elements)
    lcoe = model_writer.lcoe()
    tde = model_writer.total_discounted_energy()
    
    eco_res = [lcoe, tde, ic/tde, oc_e/tde, oc_der/tde]
    
    res['eco'] = eco_res
    
    print(res)
    
    return res

# %%
scenery_collection = {
    '0': [6, 1, 12], 

    '1': [6, 7, 12], 
    '2': [6, 7, 6],
    '3': [6, 7, 1],

    '4': [6, 1, 1],
    '5': [6, 3, 1],
    '6': [6, 5, 1],

    '7': [2, 7, 1],
    '8': [3, 7, 1],
    '9': [6, 7, 1],    
    '10': [12, 7, 1]    
}

# %%
res_sensibilidad = {}
for i in scenery_collection:
    scenes = scenery_collection[i]
    res = eval_scene(scenes[0], scenes[1], scenes[2])
    res_sensibilidad[i] = res
# Out:
# Evaluando: 6-1-12
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmp2jqw_83a.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmppnftai_p.pyomo.lp' read.
# Read time = 0.00 sec. (0.25 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmppnftai_p.pyomo.lp
# Objective sense      : Minimize
# Variables            :    2886  [Nneg: 483,  Box: 2400,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :     484
# Linear constraints   :    2884  [Less: 482,  Equal: 2402]
#   Nonzeros           :    5873
#   RHS nonzeros       :    1441
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 3027.766         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 0.0009325542     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.1703815        Max   : 1.401776
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 2423 rows and 2423 columns.
# Aggregator did 1 substitutions.
# Reduced MIP has 460 rows, 462 columns, and 1033 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (3.21 ticks)
# Found incumbent of value 3.1355258e+07 after 0.02 sec. (4.09 ticks)
# Probing time = 0.00 sec. (0.04 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 460 rows, 462 columns, and 1033 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (0.74 ticks)
# Probing time = 0.00 sec. (0.03 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.00 sec. (1.96 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.13553e+07  2359999.8932            92.47%
# *     0+    0                       3.13453e+07  2359999.8932            92.47%
#       0     0   2.22501e+07     1   3.13453e+07   2.22501e+07      361   29.02%
# *     0+    0                       2.22564e+07   2.22501e+07             0.03%
#       0     0        cutoff         2.22564e+07   2.22501e+07      361    0.03%
# Elapsed time = 0.03 sec. (7.84 ticks, tree = 0.01 MB, solutions = 3)
#
# Root node processing (before b&c):
#   Real time             =    0.03 sec. (7.96 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.02 sec. (0.18 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.05 sec. (8.14 ticks)
#
# Solution pool: 3 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  2.2256353781e+07
# Solution time =    0.05 sec.  Iterations = 361  Nodes = 0
# Deterministic time = 8.15 ticks  (173.38 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpxv55fzlo.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0       False  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  5.606634    2.803317  Resource: PV 633
# 1            True  0.000000    0.000000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [65.67437304389671, 338889.4746863685, 22.36409457956569, 40.497213667361045, 2.8130647969699103]}
# Evaluando: 6-7-12
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmprxi4x4xs.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmpl3c3qm10.pyomo.lp' read.
# Read time = 0.03 sec. (1.88 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmpl3c3qm10.pyomo.lp
# Objective sense      : Minimize
# Variables            :   20166  [Nneg: 3363,  Box: 16800,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :    3364
# Linear constraints   :   20164  [Less: 3362,  Equal: 16802]
#   Nonzeros           :   41067
#   RHS nonzeros       :   10081
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 432.5380         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 0.0002563928     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.1700282        Max   : 1.402419
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 16956 rows and 16956 columns.
# Aggregator did 1 substitutions.
# Reduced MIP has 3207 rows, 3209 columns, and 7201 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.05 sec. (21.81 ticks)
# Found incumbent of value 3.1428037e+07 after 0.08 sec. (27.97 ticks)
# Probing time = 0.00 sec. (0.29 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 3207 rows, 3209 columns, and 7201 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (4.85 ticks)
# Probing time = 0.00 sec. (0.24 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.06 sec. (50.95 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.14280e+07  2371931.4256            92.45%
# *     0+    0                       3.14180e+07  2371931.4256            92.45%
#       0     0   2.24245e+07     1   3.14180e+07   2.24245e+07     2509   28.63%
# *     0+    0                       2.24325e+07   2.24245e+07             0.04%
#       0     0        cutoff         2.24325e+07                   2510    0.00%
# Elapsed time = 0.20 sec. (96.17 ticks, tree = 0.01 MB, solutions = 3)
#
# Root node processing (before b&c):
#   Real time             =    0.20 sec. (97.03 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.20 sec. (97.03 ticks)
#
# Solution pool: 3 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  2.2432528738e+07
# Solution time =    0.20 sec.  Iterations = 2510  Nodes = 0
# Deterministic time = 97.09 ticks  (475.92 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpuox0thxo.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0       False  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  5.640896    2.820448  Resource: PV 633
# 1            True  0.000000    0.000000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [66.04583586521291, 339650.91733324697, 22.450136818550153, 40.77178880665951, 2.8239102400029696]}
# Evaluando: 6-7-6
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmppk0hekxr.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmp_0vsaznm.pyomo.lp' read.
# Read time = 0.09 sec. (4.09 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmp_0vsaznm.pyomo.lp
# Objective sense      : Minimize
# Variables            :   40326  [Nneg: 6723,  Box: 33600,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :    6724
# Linear constraints   :   40324  [Less: 6722,  Equal: 33602]
#   Nonzeros           :   81954
#   RHS nonzeros       :   20161
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 216.2690         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 2.483608e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.09261831       Max   : 1.404707
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 34825 rows and 34825 columns.
# MIP Presolve modified 280 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 5498 rows, 5500 columns, and 12123 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.09 sec. (44.82 ticks)
# Found incumbent of value 3.8379525e+07 after 0.13 sec. (56.36 ticks)
# Probing time = 0.00 sec. (0.57 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 5498 rows, 5500 columns, and 12123 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (7.53 ticks)
# Probing time = 0.02 sec. (0.43 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.17 sec. (134.30 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.83795e+07  4205219.0106            89.04%
# *     0+    0                       3.48246e+07  4205219.0106            87.92%
#       0     0   3.37597e+07     3   3.48246e+07   3.37597e+07       12    3.06%
# *     0+    0                       3.38059e+07   3.37597e+07             0.14%
# *     0+    0                       3.37792e+07   3.37597e+07             0.06%
#       0     0        cutoff         3.37792e+07   3.37792e+07       27    0.00%
# Elapsed time = 0.55 sec. (266.79 ticks, tree = 0.01 MB, solutions = 4)
#
# Implied bound cuts applied:  705
# Mixed integer rounding cuts applied:  768
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    0.55 sec. (268.78 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.55 sec. (268.78 ticks)
#
# Solution pool: 4 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  3.3779231736e+07
# Solution time =    0.55 sec.  Iterations = 27  Nodes = 0
# Deterministic time = 268.90 ticks  (491.58 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpq5qu4ruh.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  2.748004    1.374002  Resource: PV 633
# 1            True  5.600000    2.800000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [97.86821118547827, 345150.190511718, 35.143558202709904, 55.89344732161998, 6.831205661148418]}
# Evaluando: 6-7-1
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmp5rh62atp.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmpv6vcqobj.pyomo.lp' read.
# Read time = 0.55 sec. (24.56 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmpv6vcqobj.pyomo.lp
# Objective sense      : Minimize
# Variables            :  241926  [Nneg: 40323,  Box: 201600,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :   40324
# Linear constraints   :  241924  [Less: 40322,  Equal: 201602]
#   Nonzeros           :  492473
#   RHS nonzeros       :  120961
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 36.04484         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 1.810666e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.06301877       Max   : 1.559718
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 205929 rows and 205929 columns.
# MIP Presolve modified 840 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 35994 rows, 35996 columns, and 80142 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.66 sec. (433.34 ticks)
# Found incumbent of value 3.7377370e+07 after 0.84 sec. (505.11 ticks)
# Probing time = 0.05 sec. (3.62 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 35994 rows, 35996 columns, and 80142 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.17 sec. (55.19 ticks)
# Probing time = 0.02 sec. (2.77 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 1.67 sec. (613.49 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.73774e+07  3494356.6398            90.65%
#       0     0   3.23775e+07     3   3.73774e+07   3.23775e+07       31   13.38%
# *     0+    0                       3.32378e+07   3.23775e+07             2.59%
# *     0+    0                       3.24020e+07   3.23775e+07             0.08%
#       0     0        cutoff         3.24020e+07   3.24020e+07      164    0.00%
# Elapsed time = 11.28 sec. (2435.72 ticks, tree = 0.01 MB, solutions = 3)
#
# Implied bound cuts applied:  4519
# Mixed integer rounding cuts applied:  4578
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =   11.33 sec. (2446.07 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =   11.33 sec. (2446.07 ticks)
#
# Solution pool: 3 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  3.2401982216e+07
# Solution time =   11.33 sec.  Iterations = 164  Nodes = 0
# Deterministic time = 2446.77 ticks  (215.97 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmp76wymiat.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  3.526397    1.763199  Resource: PV 633
# 1            True  4.800000    2.400000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [94.15746596476166, 344125.46985895874, 34.81473308449473, 52.70976617004955, 6.632966710217347]}
# Evaluando: 6-1-1
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmp2c8bitkm.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmp7kyvxyit.pyomo.lp' read.
# Read time = 0.08 sec. (3.30 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmp7kyvxyit.pyomo.lp
# Objective sense      : Minimize
# Variables            :   34566  [Nneg: 5763,  Box: 28800,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :    5764
# Linear constraints   :   34564  [Less: 5762,  Equal: 28802]
#   Nonzeros           :   70327
#   RHS nonzeros       :   17281
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 252.3139         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 2.466779e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.06343626       Max   : 1.552617
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 29455 rows and 29455 columns.
# MIP Presolve modified 120 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 5108 rows, 5110 columns, and 11380 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.05 sec. (38.35 ticks)
# Found incumbent of value 3.7368949e+07 after 0.08 sec. (48.58 ticks)
# Probing time = 0.00 sec. (0.51 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 5108 rows, 5110 columns, and 11380 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (7.10 ticks)
# Probing time = 0.00 sec. (0.39 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.17 sec. (129.73 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.73689e+07  4040410.1146            89.19%
# *     0+    0                       3.38390e+07  4040410.1146            88.06%
#       0     0   3.23529e+07     3   3.38390e+07   3.23529e+07       11    4.39%
# *     0+    0                       3.29695e+07   3.23529e+07             1.87%
# *     0+    0                       3.23866e+07   3.23529e+07             0.10%
#       0     0        cutoff         3.23866e+07   3.23866e+07       64    0.00%
# Elapsed time = 0.53 sec. (269.62 ticks, tree = 0.01 MB, solutions = 4)
#
# Implied bound cuts applied:  657
# Mixed integer rounding cuts applied:  719
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    0.53 sec. (271.33 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.53 sec. (271.33 ticks)
#
# Solution pool: 4 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  3.2386608476e+07
# Solution time =    0.53 sec.  Iterations = 64  Nodes = 0
# Deterministic time = 271.43 ticks  (510.21 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmphzije93o.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  2.750377    1.375188  Resource: PV 633
# 1            True  5.600000    2.800000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [94.13878406541053, 344030.45245894, 35.26725153396818, 51.728075857252186, 7.143456674190084]}
# Evaluando: 6-3-1
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmp5ryjrkfl.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmpgumj3yq8.pyomo.lp' read.
# Read time = 0.22 sec. (10.22 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmpgumj3yq8.pyomo.lp
# Objective sense      : Minimize
# Variables            :  103686  [Nneg: 17283,  Box: 86400,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :   17284
# Linear constraints   :  103684  [Less: 17282,  Equal: 86402]
#   Nonzeros           :  210979
#   RHS nonzeros       :   51841
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 84.10462         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 2.737452e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.06303203       Max   : 1.559415
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 88384 rows and 88384 columns.
# MIP Presolve modified 360 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 15299 rows, 15301 columns, and 34052 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.22 sec. (138.65 ticks)
# Found incumbent of value 3.7343853e+07 after 0.30 sec. (164.41 ticks)
# Probing time = 0.00 sec. (1.54 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 15299 rows, 15301 columns, and 34052 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.05 sec. (22.11 ticks)
# Probing time = 0.02 sec. (1.18 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.39 sec. (265.57 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.73439e+07  3771628.3935            89.90%
# *     0+    0                       3.73339e+07  3771628.3935            89.90%
#       0     0   3.26171e+07     3   3.73339e+07   3.26171e+07       23   12.63%
# *     0+    0                       3.26904e+07   3.26171e+07             0.22%
# *     0+    0                       3.26367e+07   3.26171e+07             0.06%
#       0     0        cutoff         3.26367e+07   3.26367e+07       74    0.00%
# Elapsed time = 2.13 sec. (871.94 ticks, tree = 0.01 MB, solutions = 4)
#
# Implied bound cuts applied:  1926
# Mixed integer rounding cuts applied:  1997
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    2.14 sec. (877.06 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    2.14 sec. (877.06 ticks)
#
# Solution pool: 4 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  3.2636651201e+07
# Solution time =    2.14 sec.  Iterations = 74  Nodes = 0
# Deterministic time = 877.36 ticks  (409.98 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmp2ybhw4n5.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  3.508553    1.754277  Resource: PV 633
# 1            True  4.800000    2.400000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [94.92593475555162, 343811.7442343426, 34.77643620463134, 53.67066160558074, 6.4788369453394745]}
# Evaluando: 6-5-1
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmponhs_deo.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmp8huza2bu.pyomo.lp' read.
# Read time = 0.41 sec. (17.46 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmp8huza2bu.pyomo.lp
# Objective sense      : Minimize
# Variables            :  172806  [Nneg: 28803,  Box: 144000,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :   28804
# Linear constraints   :  172804  [Less: 28802,  Equal: 144002]
#   Nonzeros           :  351702
#   RHS nonzeros       :   86401
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 50.46277         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 2.107849e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.06306532       Max   : 1.558590
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 147182 rows and 147182 columns.
# MIP Presolve modified 600 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 25621 rows, 25623 columns, and 57048 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.48 sec. (269.47 ticks)
# Found incumbent of value 3.7363604e+07 after 0.61 sec. (320.66 ticks)
# Probing time = 0.03 sec. (2.57 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 25621 rows, 25623 columns, and 57048 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.11 sec. (37.91 ticks)
# Probing time = 0.01 sec. (1.97 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.88 sec. (404.85 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.73636e+07  3693052.0416            90.12%
# *     0+    0                       3.73536e+07  3693052.0416            90.11%
#       0     0   3.27517e+07     3   3.73536e+07   3.27517e+07       25   12.32%
# *     0+    0                       3.36357e+07   3.27517e+07             2.63%
# *     0+    0                       3.27753e+07   3.27517e+07             0.07%
#       0     0        cutoff         3.27753e+07   3.27753e+07      137    0.00%
# Elapsed time = 7.09 sec. (1765.46 ticks, tree = 0.01 MB, solutions = 4)
#
# Implied bound cuts applied:  3157
# Mixed integer rounding cuts applied:  3347
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    7.11 sec. (1774.01 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    7.11 sec. (1774.01 ticks)
#
# Solution pool: 4 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  3.2775327000e+07
# Solution time =    7.11 sec.  Iterations = 137  Nodes = 0
# Deterministic time = 1774.50 ticks  (249.61 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpzp1x2g4b.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  3.461696    1.730848  Resource: PV 633
# 1            True  4.800000    2.400000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [95.27794324604207, 343997.0037535869, 34.57381712450226, 54.16051147161246, 6.543614649926706]}
# Evaluando: 2-7-1
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmp6jrl7p8w.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmps32xuk7g.pyomo.lp' read.
# Read time = 0.19 sec. (7.95 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmps32xuk7g.pyomo.lp
# Objective sense      : Minimize
# Variables            :   80646  [Nneg: 13443,  Box: 67200,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :   13444
# Linear constraints   :   80644  [Less: 13442,  Equal: 67202]
#   Nonzeros           :  164100
#   RHS nonzeros       :   40321
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 108.1345         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 1.726261e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.06298978       Max   : 1.525836
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 68745 rows and 68745 columns.
# MIP Presolve modified 280 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 11898 rows, 11900 columns, and 26481 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.17 sec. (102.38 ticks)
# Found incumbent of value 3.6666644e+07 after 0.24 sec. (122.43 ticks)
# Probing time = 0.00 sec. (1.20 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 11898 rows, 11900 columns, and 26481 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.05 sec. (17.28 ticks)
# Probing time = 0.02 sec. (0.92 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.25 sec. (200.96 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.66666e+07  3579089.2154            90.24%
# *     0+    0                       3.66566e+07  3579089.2154            90.24%
#       0     0   3.26206e+07     3   3.66566e+07   3.26206e+07       17   11.01%
# *     0+    0                       3.33513e+07   3.26206e+07             2.19%
# *     0+    0                       3.26512e+07   3.26206e+07             0.09%
#       0     0        cutoff         3.26512e+07   3.26512e+07      113    0.00%
# Elapsed time = 1.42 sec. (646.73 ticks, tree = 0.01 MB, solutions = 4)
#
# Implied bound cuts applied:  1455
# Mixed integer rounding cuts applied:  1618
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    1.44 sec. (650.72 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    1.44 sec. (650.72 ticks)
#
# Solution pool: 4 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  3.2651163261e+07
# Solution time =    1.44 sec.  Iterations = 113  Nodes = 0
# Deterministic time = 650.95 ticks  (452.68 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpis5n6512.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  3.174534    1.587267  Resource: PV 633
# 1            True  4.800000    2.400000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [96.81954587660387, 337237.310562709, 34.11728507569473, 56.278826041845555, 6.4234347590634835]}
# Evaluando: 3-7-1
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmptjds4yog.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmp3ow_iww_.pyomo.lp' read.
# Read time = 0.39 sec. (11.96 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmp3ow_iww_.pyomo.lp
# Objective sense      : Minimize
# Variables            :  120966  [Nneg: 20163,  Box: 100800,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :   20164
# Linear constraints   :  120964  [Less: 20162,  Equal: 100802]
#   Nonzeros           :  246277
#   RHS nonzeros       :   60481
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 72.08967         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 2.815718e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.06316546       Max   : 1.540195
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 102840 rows and 102840 columns.
# MIP Presolve modified 420 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 18123 rows, 18125 columns, and 40403 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.39 sec. (170.13 ticks)
# Found incumbent of value 3.7049725e+07 after 0.50 sec. (206.13 ticks)
# Probing time = 0.02 sec. (1.81 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 18123 rows, 18125 columns, and 40403 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.09 sec. (26.93 ticks)
# Probing time = 0.00 sec. (1.39 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.66 sec. (307.37 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.70497e+07  3590446.8425            90.31%
# *     0+    0                       3.70397e+07  3590446.8425            90.31%
#       0     0   3.17443e+07     3   3.70397e+07   3.17443e+07       24   14.30%
# *     0+    0                       3.18994e+07   3.17443e+07             0.49%
# *     0+    0                       3.17649e+07   3.17443e+07             0.06%
#       0     0        cutoff         3.17649e+07   3.17649e+07      149    0.00%
# Elapsed time = 7.27 sec. (1138.93 ticks, tree = 0.01 MB, solutions = 4)
#
# Implied bound cuts applied:  2265
# Mixed integer rounding cuts applied:  2364
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    7.31 sec. (1144.92 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    7.31 sec. (1144.92 ticks)
#
# Solution pool: 4 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  3.1764907154e+07
# Solution time =    7.31 sec.  Iterations = 149  Nodes = 0
# Deterministic time = 1145.26 ticks  (156.61 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpwo0vhbiq.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  3.657149    1.828574  Resource: PV 633
# 1            True  4.800000    2.400000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [93.17662049498358, 340910.7025448179, 35.66080648909309, 50.90498788576546, 6.610826120124866]}
# Evaluando: 6-7-1
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmptrllqufm.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmplw0h55jr.pyomo.lp' read.
# Read time = 0.61 sec. (24.56 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmplw0h55jr.pyomo.lp
# Objective sense      : Minimize
# Variables            :  241926  [Nneg: 40323,  Box: 201600,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :   40324
# Linear constraints   :  241924  [Less: 40322,  Equal: 201602]
#   Nonzeros           :  492467
#   RHS nonzeros       :  120961
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 36.04484         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 2.062768e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.06302845       Max   : 1.558299
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 205922 rows and 205922 columns.
# MIP Presolve modified 840 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 36001 rows, 36003 columns, and 80178 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.75 sec. (436.14 ticks)
# Found incumbent of value 3.7378564e+07 after 0.95 sec. (507.92 ticks)
# Probing time = 0.02 sec. (3.62 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 36001 rows, 36003 columns, and 80178 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.11 sec. (56.65 ticks)
# Probing time = 0.02 sec. (2.77 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 1.17 sec. (574.84 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.73786e+07  3543008.5684            90.52%
#       0     0   3.25632e+07     3   3.73786e+07   3.25632e+07       28   12.88%
# *     0+    0                       3.34079e+07   3.25632e+07             2.53%
# *     0+    0                       3.25883e+07   3.25632e+07             0.08%
#       0     0        cutoff         3.25883e+07   3.25883e+07      219    0.00%
# Elapsed time = 8.48 sec. (2489.30 ticks, tree = 0.01 MB, solutions = 3)
#
# Implied bound cuts applied:  4474
# Mixed integer rounding cuts applied:  4625
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =    8.51 sec. (2499.65 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    8.51 sec. (2499.65 ticks)
#
# Solution pool: 3 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  3.2588258785e+07
# Solution time =    8.51 sec.  Iterations = 219  Nodes = 0
# Deterministic time = 2500.34 ticks  (293.64 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpddmraz3z.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True   3.49141    1.745705  Resource: PV 633
# 1            True   4.80000    2.400000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [94.68888131641594, 344161.40873176535, 34.67385773752384, 53.4487310188688, 6.566292560023453]}
# Evaluando: 12-7-1
# Creando Modelo
# Resolviendo
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmpz58h6nco.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmp14m3s6_a.pyomo.lp' read.
# Read time = 1.45 sec. (51.33 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmp14m3s6_a.pyomo.lp
# Objective sense      : Minimize
# Variables            :  483846  [Nneg: 80643,  Box: 403200,  Binary: 2,
#                                  General Integer: 1]
# Objective nonzeros   :   80644
# Linear constraints   :  483844  [Less: 80642,  Equal: 403202]
#   Nonzeros           :  984800
#   RHS nonzeros       :  241921
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 18.02242         Max   : 1520034.
# Linear constraints   :
#   Nonzeros           : Min   : 1.773759e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.06309881       Max   : 1.566163
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 412022 rows and 412022 columns.
# MIP Presolve modified 1680 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 71821 rows, 71823 columns, and 159893 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 1.91 sec. (1234.61 ticks)
# Found incumbent of value 3.7533149e+07 after 2.30 sec. (1378.00 ticks)
# Probing time = 0.05 sec. (7.22 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 71821 rows, 71823 columns, and 159893 nonzeros.
# Reduced MIP has 2 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.38 sec. (118.61 ticks)
# Probing time = 0.05 sec. (5.52 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 5.91 sec. (1808.21 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.75331e+07  3623291.6340            90.35%
#       0     0   3.25558e+07     3   3.75331e+07   3.25558e+07       58   13.26%
# *     0+    0                       3.29443e+07   3.25558e+07             1.18%
# *     0+    0                       3.25769e+07   3.25558e+07             0.06%
#       0     0        cutoff         3.25769e+07   3.25769e+07      198    0.00%
# Elapsed time = 17.49 sec. (4966.53 ticks, tree = 0.01 MB, solutions = 4)
#
# Implied bound cuts applied:  5385
# Mixed integer rounding cuts applied:  4614
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =   17.58 sec. (4990.38 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =   17.58 sec. (4990.38 ticks)
#
# Solution pool: 4 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  3.2576942464e+07
# Solution time =   17.58 sec.  Iterations = 198  Nodes = 0
# Deterministic time = 4991.76 ticks  (283.98 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpu15fw9qa.cplex.sol'.
# CPLEX> Guardando Resultados
# {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  3.576268    1.788134  Resource: PV 633
# 1            True  4.800000    2.400000  Resource: WT 633  , 'storage': Empty DataFrame
# Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
# Index: [], 'eco': [94.23585627942636, 345695.8290643165, 34.85133774376207, 52.780712014627646, 6.603806521036957]}

# %%
res_sensibilidad
# Out:
# {'0': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0       False  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  5.606634    2.803317  Resource: PV 633
#   1            True  0.000000    0.000000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [65.67437304389671,
#    338889.4746863685,
#    22.36409457956569,
#    40.497213667361045,
#    2.8130647969699103]},
#  '1': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0       False  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  5.640896    2.820448  Resource: PV 633
#   1            True  0.000000    0.000000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [66.04583586521291,
#    339650.91733324697,
#    22.450136818550153,
#    40.77178880665951,
#    2.8239102400029696]},
#  '2': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  2.748004    1.374002  Resource: PV 633
#   1            True  5.600000    2.800000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [97.86821118547827,
#    345150.190511718,
#    35.143558202709904,
#    55.89344732161998,
#    6.831205661148418]},
#  '3': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  3.526397    1.763199  Resource: PV 633
#   1            True  4.800000    2.400000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [94.15746596476166,
#    344125.46985895874,
#    34.81473308449473,
#    52.70976617004955,
#    6.632966710217347]},
#  '4': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  2.750377    1.375188  Resource: PV 633
#   1            True  5.600000    2.800000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [94.13878406541053,
#    344030.45245894,
#    35.26725153396818,
#    51.728075857252186,
#    7.143456674190084]},
#  '5': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  3.508553    1.754277  Resource: PV 633
#   1            True  4.800000    2.400000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [94.92593475555162,
#    343811.7442343426,
#    34.77643620463134,
#    53.67066160558074,
#    6.4788369453394745]},
#  '6': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  3.461696    1.730848  Resource: PV 633
#   1            True  4.800000    2.400000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [95.27794324604207,
#    343997.0037535869,
#    34.57381712450226,
#    54.16051147161246,
#    6.543614649926706]},
#  '7': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  3.174534    1.587267  Resource: PV 633
#   1            True  4.800000    2.400000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [96.81954587660387,
#    337237.310562709,
#    34.11728507569473,
#    56.278826041845555,
#    6.4234347590634835]},
#  '8': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  3.657149    1.828574  Resource: PV 633
#   1            True  4.800000    2.400000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [93.17662049498358,
#    340910.7025448179,
#    35.66080648909309,
#    50.90498788576546,
#    6.610826120124866]},
#  '9': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True   3.49141    1.745705  Resource: PV 633
#   1            True   4.80000    2.400000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [94.68888131641594,
#    344161.40873176535,
#    34.67385773752384,
#    53.4487310188688,
#    6.566292560023453]},
#  '10': {'sgen':      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
#   0  PV 633    2   0.0     0.0     NaN      1.0        True  wye
#   1  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#      current_source  max_p_mw  max_q_mvar             model
#   0            True  3.576268    1.788134  Resource: PV 633
#   1            True  4.800000    2.400000  Resource: WT 633  ,
#   'storage': Empty DataFrame
#   Columns: [name, bus, p_mw, q_mvar, sn_mva, soc_percent, min_e_mwh, max_e_mwh, scaling, in_service, type, model]
#   Index: [],
#   'eco': [94.23585627942636,
#    345695.8290643165,
#    34.85133774376207,
#    52.780712014627646,
#    6.603806521036957]}}

# %% [markdown]
# # Results

# %%
import numpy as np

# %%
import matplotlib.colors as mcolors

# %%
scenery_collection
# Out:
# {'0': [6, 1, 12],
#  '1': [6, 7, 12],
#  '2': [6, 7, 6],
#  '3': [6, 7, 1],
#  '4': [6, 1, 1],
#  '5': [6, 3, 1],
#  '6': [6, 5, 1],
#  '7': [2, 7, 1],
#  '8': [3, 7, 1],
#  '9': [6, 7, 1],
#  '10': [12, 7, 1]}

# %%
columns = ["{0}-{1}-{2}".format(v[0], v[1], v[2]) for v in scenery_collection.values()]
columns
# Out:
# ['6-1-12',
#  '6-7-12',
#  '6-7-6',
#  '6-7-1',
#  '6-1-1',
#  '6-3-1',
#  '6-5-1',
#  '2-7-1',
#  '3-7-1',
#  '6-7-1',
#  '12-7-1']

# %%
rows = ['Initial Cost', 'External Energy', 'Operating Cost']

# %%
data = [res_sensibilidad[k]['eco'][2:] for k in res_sensibilidad.keys()]

# %%
data
# Out:
# [[22.36409457956569, 40.497213667361045, 2.8130647969699103],
#  [22.450136818550153, 40.77178880665951, 2.8239102400029696],
#  [35.143558202709904, 55.89344732161998, 6.831205661148418],
#  [34.81473308449473, 52.70976617004955, 6.632966710217347],
#  [35.26725153396818, 51.728075857252186, 7.143456674190084],
#  [34.77643620463134, 53.67066160558074, 6.4788369453394745],
#  [34.57381712450226, 54.16051147161246, 6.543614649926706],
#  [34.11728507569473, 56.278826041845555, 6.4234347590634835],
#  [35.66080648909309, 50.90498788576546, 6.610826120124866],
#  [34.67385773752384, 53.4487310188688, 6.566292560023453],
#  [34.85133774376207, 52.780712014627646, 6.603806521036957]]

# %%
data[0]
# Out:
# [22.36409457956569, 40.497213667361045, 2.8130647969699103]

# %%
fig, ax = plt.subplots(1, 1)

fig.set_size_inches(10,6)
    
values = np.arange(0, 2500, 500)
value_increment = 1000

# Get some pastel shades for the colors
colors = [color for name, color in mcolors.TABLEAU_COLORS.items()]
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.6

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

for col in range(len(columns)):
    y_offset = 0
    for d in range(len(data[col])):
        dat = data[col][d]
        plt.bar(0.5 + 1*col, dat, bar_width, bottom=y_offset, color =colors[d])
        y_offset += dat


# Adjust layout to make room for the table:
#plt.subplots_adjust(left=0.2, bottom=0.2)

plt.ylabel("LCOE in USD/MWh")
plt.xlabel("Granularity")
#plt.yticks(values * value_increment, ['%d' % val for val in values])
plt.xticks([0.5 + i for i in range(12)], columns + [''])
plt.title('LCOE Sensitivity Analysis')

ax.legend(rows, loc = 'center right')

plt.show()
