# %% [markdown]
# ## Ejemplo de Aplicación con la red IEEE 13 modificada ##

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import math

# %%
import pandapower as pp

# %%
import pandas as pd

# %%
import pyomo.environ as pe

# %%
import matplotlib.pyplot as plt

# %%
import ModelWriters as mw

# %%
import ModelWriters.Scenes as Scenes

# %%
import ModelWriters.Resources as Resources

# %%
import ModelWriters.Simulation as Simulation

# %% [markdown]
# Creating Network

# %%
net = pp.create_empty_network()

# %% [markdown]
# Adding line parameter data:

# %%
line_data = {"c_nf_per_km": 0, "r_ohm_per_km": 0.40, "x_ohm_per_km": 0.30, "max_i_ka": 0.300, "type": "al", "q_mm2": 95, "alpha": 4.03e-3}
pp.create_std_type(net, line_data, "AlAc 95", element='line')

line_data = {"c_nf_per_km": 0, "r_ohm_per_km": 0.50, "x_ohm_per_km": 0.35, "max_i_ka": 0.250, "type": "al", "q_mm2": 70, "alpha": 4.03e-3}
pp.create_std_type(net, line_data, "AlAc 70", element='line')

line_data = {"c_nf_per_km": 0, "r_ohm_per_km": 0.70, "x_ohm_per_km": 0.40, "max_i_ka": 0.190, "type": "al", "q_mm2": 50, "alpha": 4.03e-3}
pp.create_std_type(net, line_data, "AlAc 50", element='line')

line_data = {"c_nf_per_km": 0, "r_ohm_per_km": 1.20, "x_ohm_per_km": 0.45, "max_i_ka": 0.130, "type": "al", "q_mm2": 25, "alpha": 4.03e-3}
pp.create_std_type(net, line_data, "AlAc 25", element='line')

# %%
b650 = pp.create_bus(net, name='650', vn_kv=13.2) 

pp.create_ext_grid(net, name='Ext Grid', bus=b650)

b632 = pp.create_bus(net, name='632', vn_kv=13.2) 
b633 = pp.create_bus(net, name='633', vn_kv=13.2) 
b645 = pp.create_bus(net, name='645', vn_kv=13.2) 
b646 = pp.create_bus(net, name='646', vn_kv=13.2) 

b671 = pp.create_bus(net, name='671', vn_kv=13.2)  
b675 = pp.create_bus(net, name='675', vn_kv=13.2) 

b611 = pp.create_bus(net, name='611', vn_kv=13.2) 
b684 = pp.create_bus(net, name='684', vn_kv=13.2) 
b652 = pp.create_bus(net, name='652', vn_kv=13.2) 

pp.create_line(net, name='L 650-632', from_bus=b650, to_bus=b632, length_km=2.0, std_type="AlAc 95") 
pp.create_line(net, name='L 632-671', from_bus=b632, to_bus=b671, length_km=2.0, std_type="AlAc 95") 
pp.create_line(net, name='L 671-684', from_bus=b671, to_bus=b684, length_km=1.5, std_type="AlAc 70") 

pp.create_line(net, name='L 632-645', from_bus=b632, to_bus=b645, length_km=0.5, std_type="AlAc 50") 
pp.create_line(net, name='L 645-646', from_bus=b645, to_bus=b646, length_km=0.5, std_type="AlAc 50") 
pp.create_line(net, name='L 632-633', from_bus=b632, to_bus=b633, length_km=1.0, std_type="AlAc 50") 
pp.create_line(net, name='L 671-675', from_bus=b671, to_bus=b675, length_km=1.0, std_type="AlAc 50") 
pp.create_line(net, name='L 684-611', from_bus=b684, to_bus=b611, length_km=0.5, std_type="AlAc 25") 
pp.create_line(net, name='L 684-652', from_bus=b684, to_bus=b652, length_km=1.0, std_type="AlAc 25") 

pp.create_load(net, bus=b645, p_mw=1.20, q_mvar = 0.58)
pp.create_load(net, bus=b646, p_mw=1.50, q_mvar = 0.58*1.5/1.2)
pp.create_load(net, bus=b633, p_mw=0.80, q_mvar = math.sqrt((0.80/0.85)**2-0.8**2))
pp.create_load(net, bus=b675, p_mw=0.90, q_mvar = math.sqrt((0.90/0.85)**2-0.9**2))
pp.create_load(net, bus=b611, p_mw=0.50, q_mvar = math.sqrt((0.50/0.80)**2-0.5**2))
pp.create_load(net, bus=b652, p_mw=0.60, q_mvar = math.sqrt((0.60/0.80)**2-0.6**2))


pp.create_sgen(net, name='PV 684', bus=b684, p_mw=0.00, q_mvar=0.00, max_p_mw=0.00, max_q_mvar=0.00)
pp.create_sgen(net, name='PV 633', bus=b633, p_mw=0.00, q_mvar=0.00, max_p_mw=0.00, max_q_mvar=0.00)
pp.create_sgen(net, name='PV 646', bus=b646, p_mw=0.00, q_mvar=0.00, max_p_mw=0.00, max_q_mvar=0.00)

pp.create_sgen(net, name='WT 633', bus=b633, p_mw=0.00, q_mvar=0.00, max_p_mw=0.00, max_q_mvar=0.00)

pp.create_storage(net, name='ST 684', bus=b684, p_mw=0.00, q_mvar=0.00, max_p_mw=0.00, max_q_mvar=0.00, max_e_mwh = 0.0)
pp.create_storage(net, name='ST 632', bus=b632, p_mw=0.00, q_mvar=0.00, max_p_mw=0.00, max_q_mvar=0.00, max_e_mwh = 0.0)
# Out:
# 1

# %%
net.bus
# Out:
#   name  vn_kv type  zone  in_service
# 0  650   13.2    b  None        True
# 1  632   13.2    b  None        True
# 2  633   13.2    b  None        True
# 3  645   13.2    b  None        True
# 4  646   13.2    b  None        True
# 5  671   13.2    b  None        True
# 6  675   13.2    b  None        True
# 7  611   13.2    b  None        True
# 8  684   13.2    b  None        True
# 9  652   13.2    b  None        True

# %%
net.ext_grid
# Out:
#        name  bus  vm_pu  va_degree  in_service
# 0  Ext Grid    0    1.0        0.0        True

# %%
net.sgen
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 684    8   0.0     0.0     NaN      1.0        True  wye
# 1  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 2  PV 646    4   0.0     0.0     NaN      1.0        True  wye
# 3  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar
# 0            True       0.0         0.0
# 1            True       0.0         0.0
# 2            True       0.0         0.0
# 3            True       0.0         0.0

# %%
net.load
# Out:
#    name  bus  p_mw    q_mvar  const_z_percent  const_i_percent  sn_mva  \
# 0  None    3   1.2  0.580000              0.0              0.0     NaN
# 1  None    4   1.5  0.725000              0.0              0.0     NaN
# 2  None    2   0.8  0.495795              0.0              0.0     NaN
# 3  None    6   0.9  0.557770              0.0              0.0     NaN
# 4  None    7   0.5  0.375000              0.0              0.0     NaN
# 5  None    9   0.6  0.450000              0.0              0.0     NaN
#
#    scaling  in_service type
# 0      1.0        True  wye
# 1      1.0        True  wye
# 2      1.0        True  wye
# 3      1.0        True  wye
# 4      1.0        True  wye
# 5      1.0        True  wye

# %%
net.storage
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  soc_percent  min_e_mwh  max_e_mwh  \
# 0  ST 684    8   0.0     0.0     NaN          NaN        0.0        0.0
# 1  ST 632    1   0.0     0.0     NaN          NaN        0.0        0.0
#
#    scaling  in_service  type  max_p_mw  max_q_mvar
# 0      1.0        True  None       0.0         0.0
# 1      1.0        True  None       0.0         0.0

# %%
 pp.runpp(net)

# %%
net.res_bus
# Out:
#       vm_pu  va_degree      p_mw    q_mvar
# 0  1.000000   0.000000 -5.787786 -3.390437
# 1  0.961761  -0.259960  0.000000  0.000000
# 2  0.957214  -0.250296  0.800000  0.495795
# 3  0.954492  -0.289781  1.200000  0.580000
# 4  0.950446  -0.306545  1.500000  0.725000
# 5  0.946893  -0.294868  0.000000  0.000000
# 6  0.941694  -0.283643  0.900000  0.557770
# 7  0.936815  -0.238107  0.500000  0.375000
# 8  0.939170  -0.280154  0.000000  0.000000
# 9  0.933497  -0.178884  0.600000  0.450000

# %%
net.res_line
# Out:
#    p_from_mw  q_from_mvar   p_to_mw  q_to_mvar     pl_mw   ql_mvar  i_from_ka  \
# 0   5.787786     3.390437 -5.581204  -3.235501  0.206582  0.154936   0.293387
# 1   2.051226     1.417575 -2.020366  -1.394430  0.030860  0.023145   0.113394
# 2   1.115287     0.833758 -1.105978  -0.827242  0.009309  0.006516   0.064321
# 3   2.726094     1.319911 -2.706172  -1.308527  0.019922  0.011384   0.137744
# 4   1.506172     0.728527 -1.500000  -0.725000  0.006172  0.003527   0.076669
# 5   0.803884     0.498015 -0.800000  -0.495795  0.003884  0.002219   0.043006
# 6   0.905079     0.560672 -0.900000  -0.557770  0.005079  0.002902   0.049179
# 7   0.501533     0.375575 -0.500000  -0.375000  0.001533  0.000575   0.029180
# 8   0.604446     0.451667 -0.600000  -0.450000  0.004446  0.001667   0.035141
#
#     i_to_ka      i_ka  vm_from_pu  va_from_degree  vm_to_pu  va_to_degree  \
# 0  0.293387  0.293387    1.000000        0.000000  0.961761     -0.259960
# 1  0.113394  0.113394    0.961761       -0.259960  0.946893     -0.294868
# 2  0.064321  0.064321    0.946893       -0.294868  0.939170     -0.280154
# 3  0.137744  0.137744    0.961761       -0.259960  0.954492     -0.289781
# 4  0.076669  0.076669    0.954492       -0.289781  0.950446     -0.306545
# 5  0.043006  0.043006    0.961761       -0.259960  0.957214     -0.250296
# 6  0.049179  0.049179    0.946893       -0.294868  0.941694     -0.283643
# 7  0.029180  0.029180    0.939170       -0.280154  0.936815     -0.238107
# 8  0.035141  0.035141    0.939170       -0.280154  0.933497     -0.178884
#
#    loading_percent
# 0        97.795574
# 1        37.798022
# 2        25.728549
# 3        72.496695
# 4        40.351960
# 5        22.634647
# 6        25.883659
# 7        22.446475
# 8        27.031511

# %%
print(net)
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (10 elements)
#    - load (6 elements)
#    - sgen (4 elements)
#    - storage (2 elements)
#    - ext_grid (1 element)
#    - line (9 elements)
#  and the following results tables:
#    - res_bus (10 elements)
#    - res_line (9 elements)
#    - res_ext_grid (1 element)
#    - res_load (6 elements)
#    - res_sgen (4 elements)
#    - res_storage (2 elements)

# %% [markdown]
# ## Construcción de Escenarios

# %%
Mean_Monthly_Solar_Irradiance = [7.5e3, 7.2e3, 6.5e3, 5.5e3, 4.5e3, 3.5e3, 2.5e3, 3.5e3, 4.5e3, 6.0e3, 7.0e3, 8.5e3]

# %%
sun_synth = Simulation.MonthlySolarIrradianceSimulator(latitude = -40.5490, longitude = -62.2438, 
                                                       monthly_average_irradiation = Mean_Monthly_Solar_Irradiance)

# %%
wind_synth = Simulation.Weibull(c = 7.5 / 0.886, k = 2)

# %%
wind_synth = Simulation.CorrelatedWeibull(c = 7.5 / 0.886, k = 2)

# %%
#s = Scenes.SceneBuilder(years = 4, subperiods = 1, days_in_subperiods = 1, dt=24, growth_rate = 0.025, discount_rate = 0.05)
#s = Scenes.SceneBuilder(years = 4, subperiods = 4, days_in_subperiods = 1, dt=1, growth_rate = 0.025, discount_rate = 0.05)
#s = Scenes.SceneBuilder(years = 20, subperiods = 4, days_in_subperiods = 5, dt=2, growth_rate = 0.025, discount_rate = 0.03)
#s = Scenes.SceneBuilder(years = 20, subperiods = 12, days_in_subperiods = 7, growth_rate = 0.025, discount_rate = 0.03)
#s = Scenes.SceneBuilder(years = 20, subperiods = 1, days_in_subperiods = 365, dt = 1, growth_rate = 0.025, discount_rate = 0.03)
s = Scenes.SceneBuilder(years = 20, subperiods = 6, days_in_subperiods = 2, dt = 1, growth_rate = 0.025, discount_rate = 0.10)
s.additional_columns['solar_irradiance'] = sun_synth
s.additional_columns['wind_speed'] = wind_synth
scenes = s.build_scenes()
scenes
# Out:
#       year    day         dd  hour   dt   growth  discount  solar_irradiance  \
# 0      0.0    0.0  30.416667   0.0  1.0  1.00000  1.000000               0.0
# 1      0.0    0.0  30.416667   1.0  1.0  1.00000  1.000000               0.0
# 2      0.0    0.0  30.416667   2.0  1.0  1.00000  1.000000               0.0
# 3      0.0    0.0  30.416667   3.0  1.0  1.00000  1.000000               0.0
# 4      0.0    0.0  30.416667   4.0  1.0  1.00000  1.000000               0.0
# ...    ...    ...        ...   ...  ...      ...       ...               ...
# 5755  19.0  301.0  30.416667  19.0  1.0  1.59865  0.163508               0.0
# 5756  19.0  301.0  30.416667  20.0  1.0  1.59865  0.163508               0.0
# 5757  19.0  301.0  30.416667  21.0  1.0  1.59865  0.163508               0.0
# 5758  19.0  301.0  30.416667  22.0  1.0  1.59865  0.163508               0.0
# 5759  19.0  301.0  30.416667  23.0  1.0  1.59865  0.163508               0.0
#
#       wind_speed
# 0       0.746246
# 1       1.355752
# 2       2.359728
# 3       2.939646
# 4       3.005598
# ...          ...
# 5755    7.500563
# 5756    8.582718
# 5757    8.495920
# 5758    6.884013
# 5759    5.385799
#
# [5760 rows x 9 columns]

# %% [markdown]
# ## External Data Loading

# %% [markdown]
# ### Residential User, summer and winter cases

# %%
residential_user_summer = pd.read_csv('.\\Data\\UserResSum.csv', header = None, squeeze = True)

# %%
residential_user_winter = pd.read_csv('.\\Data\\UserResWin.csv', header = None, squeeze = True)

# %% [markdown]
# Data is loaded to a data syntethizer:

# %%
Residential_Synth = Simulation.DailyInterpolator( post_random_up=0.15, post_random_down=0.15)

#data is hourly, 24 hs
hours = [h for h in range(24)]

Residential_Synth.add_day(172, hours, residential_user_summer)   #north hemisfere convention, summer is June 21st
Residential_Synth.add_day(355, hours, residential_user_winter)   #north hemisfere convention, summer is June 21st

# %% [markdown]
# ### Commercial User, summer and winter cases

# %%
commercial_user_summer = pd.read_csv('.\\Data\\UserComSum.csv', header = None, squeeze = True)

# %%
commercial_user_winter = pd.read_csv('.\\Data\\UserComWin.csv', header = None, squeeze = True)

# %% [markdown]
# Data is loaded to a data syntethizer:

# %%
Commercial_Synth = Simulation.DailyInterpolator( post_random_up=0.15, post_random_down=0.15)
Commercial_Synth.add_day(172, hours, commercial_user_summer)   #north hemisfere convention, summer is June 21st
Commercial_Synth.add_day(355, hours, commercial_user_winter)   #north hemisfere convention, summer is June 21st

# %% [markdown]
# ### Industrial User, summer and winter cases

# %%
industrial_user_summer = pd.read_csv('.\\Data\\UserIndSum.csv', header = None, squeeze = True)

# %%
industrial_user_winter = pd.read_csv('.\\Data\\UserIndWin.csv', header = None, squeeze = True)

# %% [markdown]
# Data is loaded to a data syntethizer:

# %%
Industrial_Synth = Simulation.DailyInterpolator( post_random_up=0.05, post_random_down=0.05)
Industrial_Synth.add_day(172, hours, industrial_user_summer)   #north hemisfere convention, summer is June 21st
Industrial_Synth.add_day(355, hours, industrial_user_winter)   #north hemisfere convention, summer is June 21st

# %% [markdown]
# Example using Residential User:

# %%
res = [Residential_Synth.simulate(scenes.iloc[i]) for i in range(len(scenes))]

# %%
fig, ax = plt.subplots(1, 1)

fig.set_size_inches(10,6)
    
ax.plot(res[240:480])
    
ax.set_xlabel('scene')
ax.set_ylabel('P[pu]')

ax.legend()

ax.grid(True)


plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
def plot_results(results, a = 0, b = 240, items = None, elements = False, lines = False, l_ep = False):
    # Set the plot curve with markers and a title
    if not (elements or lines or l_ep or items):
        raise Exception("Nothing to plot")
    
    fig, ax = plt.subplots(1, 1)

    fig.set_size_inches(10,6)
    
    for col in results:
        p = False
        if items and col in items:
            p = True
        elif col[0:2] == 'L ':
            if col[-4:] == 'ep_h':
                if l_ep:
                    p = True
            elif lines:
                p = True
        elif elements:
            p = True

        if p:
            ax.plot(results[col][a:b], label = col)
    
    ax.set_xlabel('time')
    ax.set_ylabel('P[mw]')

    ax.legend()

    ax.grid(True)


    plt.show()

# %% [markdown]
# # LCOE without DG.

# %% [markdown]
# ## Optimization models

# %%
mw.network_precondition(net)

# %%
net.ext_grid['model'][0] = Resources.ExtGrid('SET', pr_mw = 10.0, peak_value=150, valley_value=80, rest_value=100)

# %%
net.load['model'][0] = Resources.Load('645', pr_mw = 1.20, pa_pu = Industrial_Synth)
net.load['model'][1] = Resources.Load('646', pr_mw = 1.50, pa_pu = Industrial_Synth)
net.load['model'][2] = Resources.Load('633', pr_mw = 0.80, pa_pu = Commercial_Synth)
net.load['model'][3] = Resources.Load('675', pr_mw = 0.90, pa_pu = Commercial_Synth)
net.load['model'][4] = Resources.Load('611', pr_mw = 0.50, pa_pu = Residential_Synth)
net.load['model'][5] = Resources.Load('652', pr_mw = 0.60, pa_pu = Residential_Synth)

# %%
net.sgen['model'][0] = Resources.PVGenerator('PV 684', ic_0_mu = 10.0e3, ic_1_mu = 1.35e6*0.7, oc_0_mu = 15.0e3/8760, oc_1_mu = 0.0)
net.sgen['model'][1] = Resources.PVGenerator('PV 633', ic_0_mu = 10.0e3, ic_1_mu = 1.35e6*0.7, oc_0_mu = 15.0e3/8760, oc_1_mu = 0.0)
net.sgen['model'][2] = Resources.PVGenerator('PV 646', ic_0_mu = 10.0e3, ic_1_mu = 1.35e6*0.7, oc_0_mu = 15.0e3/8760, oc_1_mu = 0.0)

net.sgen['model'][3] = Resources.WTGeneratorDiscrete('WT 633', ic_0_mu = 10.0e3, unit_size_mw = 0.800, unit_cost_mu = 1200e3*0.7, oc_0_mu = 0.00,
                                                     oc_1_mu = 15.0, cut_in = 3.0, v_rated = 12.0, cut_out = 34.0)   #Enercom E-53 800 kW
#net.sgen['model'][2] = Resources.PVGeneratorDiscrete('PV2', unit_size_mw = 0.05, unit_cost_mu = 51e3, oc_0_mu = 0.03, oc_1_mu = 0.0)

# %%
#net.storage['model'][0] = Resources.Storage('ST 684', ic_1_mu = 554e3, ic_1_mu_cap = 1000e3, oc_1_mu = 2.28*4, eta_bb = 0.8, sigma = 2.1e-3)
#net.storage['model'][1] = Resources.Storage('ST 632', ic_1_mu = 554e3, ic_1_mu_cap = 1000e3, oc_1_mu = 2.28*4, eta_bb = 0.8, sigma = 2.1e-3)
#net.storage['model'][0] = Resources.Storage('ST 684', ic_1_mu = 300e3, ic_1_mu_cap = 500e3, oc_1_mu = 2.28*4/4, eta_bb = 0.8, sigma = 2.1e-3)
#net.storage['model'][1] = Resources.Storage('ST 632', ic_1_mu = 300e3, ic_1_mu_cap = 500e3, oc_1_mu = 2.28*4/4, eta_bb = 0.8, sigma = 2.1e-3)

net.storage['model'][0] = Resources.Storage('ST 684', ic_0_mu = 10e3, ic_1_mu = 100.0e3*0.7, ic_1_mu_cap = 1000e3*0.7, oc_0_mu = 15e3/8760, oc_1_mu = 0.0, eta_bb = 0.9, sigma = 2.1e-3)
net.storage['model'][1] = Resources.Storage('ST 632', ic_0_mu = 10e3, ic_1_mu = 100.0e3*0.7, ic_1_mu_cap = 1000e3*0.7, oc_0_mu = 15e3/8760, oc_1_mu = 0.0, eta_bb = 0.9, sigma = 2.1e-3)

# %%
net.sgen
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 684    8   0.0     0.0     NaN      1.0        True  wye
# 1  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 2  PV 646    4   0.0     0.0     NaN      1.0        True  wye
# 3  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True       0.0         0.0  Resource: PV 684
# 1            True       0.0         0.0  Resource: PV 633
# 2            True       0.0         0.0  Resource: PV 646
# 3            True       0.0         0.0  Resource: WT 633

# %%
net.storage
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  soc_percent  min_e_mwh  max_e_mwh  \
# 0  ST 684    8   0.0     0.0     NaN          NaN        0.0        0.0
# 1  ST 632    1   0.0     0.0     NaN          NaN        0.0        0.0
#
#    scaling  in_service  type  max_p_mw  max_q_mvar             model
# 0      1.0        True  None       0.0         0.0  Resource: ST 684
# 1      1.0        True  None       0.0         0.0  Resource: ST 632

# %% [markdown]
# # LCOE without DERs

# %% [markdown]
# ## Model Creation

# %%
#model_writer = mw.MultiBusbarModelWriter(net, scenes, overload_cost = 2.0)
#model_writer = mw.MultiBusbarModelWriter(net, scenes, overload_cost = None)
#model_writer = mw.MultiBusbarModelWriter(net, scenes, overload_hours = 4000)
model_writer = mw.MultiBusbarModelWriter(net, scenes, overload_cost = None, overload_hours = None, max_i_pu = 1.2)

# %%
model = model_writer.create_model()

# %%
if len(scenes) < 40:
    model.pprint()

# %% [markdown]
# ### Additional Constraints
#
# 1) No PV plant
# 2) No Storage
# 3) No WTG

# %%
model_writer.additional_constraint("no_PV", net.sgen['model'][0].create + net.sgen['model'][1].create + net.sgen['model'][2].create == 0)
model_writer.additional_constraint("no_ST", net.storage['model'][0].create + net.storage['model'][1].create  == 0)

# %%
model_writer.additional_constraint("no_WT", net.sgen['model'][3].create == 0)

# %% [markdown]
# ## Resolution

# %%
opt = pe.SolverFactory('cplex')
result_obj= opt.solve(model, tee=True)
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmpy92t23t1.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmpx3jhsf4c.pyomo.lp' read.
# Read time = 0.28 sec. (12.88 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmpx3jhsf4c.pyomo.lp
# Objective sense      : Minimize
# Variables            :  103696  [Nneg: 34569,  Box: 57600,  Free: 11520,
#                                  Binary: 6,  General Integer: 1]
# Objective nonzeros   :   11534
# Linear constraints   :  138253  [Less: 69128,  Equal: 69125]
#   Nonzeros           :  307256
#   RHS nonzeros       :   34561
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 74.60052         Max   : 1085474.
# Linear constraints   :
#   Nonzeros           : Min   : 2.768879e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.05306375       Max   : 1.566390
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 1 time.
# MIP Presolve eliminated 138253 rows and 103696 columns.
# MIP Presolve modified 720 coefficients.
# All rows and columns eliminated.
# Presolve time = 0.13 sec. (88.15 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.19 sec. (110.43 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.19 sec. (110.43 ticks)
#
# Solution pool: 1 solution saved.
#
# MIP - Integer optimal solution:  Objective =  3.0234498895e+07
# Solution time =    0.19 sec.  Iterations = 0  Nodes = 0 (1)
# Deterministic time = 110.73 ticks  (588.98 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpp10xerj5.cplex.sol'.
# CPLEX>

# %%
model_writer.backconfigure_network()

# %%
model_writer.net.sgen
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 684    8   0.0     0.0     NaN      1.0       False  wye
# 1  PV 633    2   0.0     0.0     NaN      1.0       False  wye
# 2  PV 646    4   0.0     0.0     NaN      1.0       False  wye
# 3  WT 633    2   0.0     0.0     NaN      1.0       False  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True       0.0         0.0  Resource: PV 684
# 1            True       0.0         0.0  Resource: PV 633
# 2            True       0.0         0.0  Resource: PV 646
# 3            True       0.0         0.0  Resource: WT 633

# %%
model_writer.net.storage
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  soc_percent  min_e_mwh  max_e_mwh  \
# 0  ST 684    8   0.0     0.0     NaN          NaN        0.0        0.0
# 1  ST 632    1   0.0     0.0     NaN          NaN        0.0        0.0
#
#    scaling  in_service  type  max_p_mw  max_q_mvar             model
# 0      1.0       False  None       0.0         0.0  Resource: ST 684
# 1      1.0       False  None       0.0         0.0  Resource: ST 632

# %%
Resultados = model_writer.get_scenes_results()

# %%
Resultados
# Out:
#       SET_p_mw  645_p_mw  646_p_mw  633_p_mw  675_p_mw  611_p_mw  652_p_mw  \
# 0     2.322764 -0.674143 -0.823506 -0.173875 -0.220209 -0.208597 -0.222434
# 1     1.929609 -0.627122 -0.787896 -0.140952 -0.184316 -0.090045 -0.099278
# 2     1.847957 -0.674307 -0.776600 -0.134481 -0.141891 -0.056046 -0.064631
# 3     1.893291 -0.650220 -0.818748 -0.125901 -0.159627 -0.067184 -0.071611
# 4     1.870465 -0.641876 -0.836045 -0.119829 -0.133828 -0.065900 -0.072986
# ...        ...       ...       ...       ...       ...       ...       ...
# 5755  4.409518 -0.957437 -1.214890 -0.627962 -0.785792 -0.366176 -0.457262
# 5756  4.409669 -0.974709 -1.209995 -0.623788 -0.599564 -0.444670 -0.556943
# 5757  4.141414 -0.889929 -1.171872 -0.548028 -0.636375 -0.380727 -0.514483
# 5758  3.503768 -0.795651 -0.997251 -0.374338 -0.424991 -0.427983 -0.483554
# 5759  3.012644 -0.695640 -0.913267 -0.313012 -0.392922 -0.316198 -0.381605
#
#       L 650_632_pf_mw  L 632_671_pf_mw  L 671_684_pf_mw  L 632_645_pf_mw  \
# 0           -2.322764        -0.651240        -0.431031        -1.497649
# 1           -1.929609        -0.373640        -0.189323        -1.415018
# 2           -1.847957        -0.262569        -0.120677        -1.450908
# 3           -1.893291        -0.298421        -0.138795        -1.468968
# 4           -1.870465        -0.272714        -0.138886        -1.477921
# ...               ...              ...              ...              ...
# 5755        -4.409518        -1.609229        -0.823437        -2.172327
# 5756        -4.409669        -1.601176        -1.001613        -2.184704
# 5757        -4.141414        -1.531585        -0.895209        -2.061801
# 5758        -3.503768        -1.336528        -0.911537        -1.792902
# 5759        -3.012644        -1.090725        -0.697803        -1.608907
#
#       L 645_646_pf_mw  L 632_633_pf_mw  L 671_675_pf_mw  L 684_611_pf_mw  \
# 0           -0.823506        -0.173875        -0.220209        -0.208597
# 1           -0.787896        -0.140952        -0.184316        -0.090045
# 2           -0.776600        -0.134481        -0.141891        -0.056046
# 3           -0.818748        -0.125901        -0.159627        -0.067184
# 4           -0.836045        -0.119829        -0.133828        -0.065900
# ...               ...              ...              ...              ...
# 5755        -1.214890        -0.627962        -0.785792        -0.366176
# 5756        -1.209995        -0.623788        -0.599564        -0.444670
# 5757        -1.171872        -0.548028        -0.636375        -0.380727
# 5758        -0.997251        -0.374338        -0.424991        -0.427983
# 5759        -0.913267        -0.313012        -0.392922        -0.316198
#
#       L 684_652_pf_mw
# 0           -0.222434
# 1           -0.099278
# 2           -0.064631
# 3           -0.071611
# 4           -0.072986
# ...               ...
# 5755        -0.457262
# 5756        -0.556943
# 5757        -0.514483
# 5758        -0.483554
# 5759        -0.381605
#
# [5760 rows x 16 columns]

# %%
plot_results(Resultados, a = 0, b = 360, elements = True, lines = False, l_ep = False)

# %%
eco_res = {}

# %%
der_elements = [net.sgen['model'][0], net.sgen['model'][1],  net.sgen['model'][2], net.sgen['model'][3], 
                net.storage['model'][0], net.storage['model'][1]]

# %%
ext_elements = [net.ext_grid['model'][0]]

# %%
lcoe = model_writer.lcoe()

# %%
tde = model_writer.total_discounted_energy()

# %%
ic = pe.value(model_writer.initial_cost_expression())

# %%
oc_e = model_writer.opetaring_costs_value(ext_elements)
oc_e
# Out:
# 30234498.89520301

# %%
oc_der = model_writer.opetaring_costs_value(der_elements)
oc_der
# Out:
# 0.0

# %%
eco_res['No DER'] = [lcoe, tde, ic/tde, oc_e/tde, oc_der/tde]
eco_res
# Out:
# {'No DER': [108.7257451278002, 278080.4018373411, 0.0, 108.7257451278002, 0.0]}

# %% [markdown]
# # LCOE with PVs

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Additional Constraints
#
# 1) One PV plant
# 2) No Storage

# %%
model_writer.remove_constraint("no_PV")

# %%
model_writer.additional_constraint("one_PV", net.sgen['model'][0].create + net.sgen['model'][1].create + net.sgen['model'][2].create <= 1)

# %% [markdown]
# ## Resolution

# %%
opt = pe.SolverFactory('cplex')
result_obj= opt.solve(model, tee=True)
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmp_kvjhrzo.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmpty54qs81.pyomo.lp' read.
# Read time = 0.23 sec. (12.95 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmpty54qs81.pyomo.lp
# Objective sense      : Minimize
# Variables            :  103696  [Nneg: 34569,  Box: 57600,  Free: 11520,
#                                  Binary: 6,  General Integer: 1]
# Objective nonzeros   :   11534
# Linear constraints   :  138253  [Less: 69129,  Equal: 69124]
#   Nonzeros           :  307256
#   RHS nonzeros       :   34562
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 74.60052         Max   : 1085474.
# Linear constraints   :
#   Nonzeros           : Min   : 2.768879e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.05306375       Max   : 1.566390
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 116649 rows and 82090 columns.
# MIP Presolve modified 720 coefficients.
# Aggregator did 12000 substitutions.
# Reduced MIP has 9604 rows, 9606 columns, and 24009 nonzeros.
# Reduced MIP has 3 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.25 sec. (129.71 ticks)
# Found incumbent of value 3.0234499e+07 after 0.30 sec. (158.07 ticks)
# Probing time = 0.02 sec. (1.64 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 3 coefficients.
# Reduced MIP has 9604 rows, 9606 columns, and 24009 nonzeros.
# Reduced MIP has 3 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.66 ticks)
# Probing time = 0.00 sec. (1.81 ticks)
# Clique table members: 1.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.27 sec. (162.05 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.02345e+07   1.73596e+07            42.58%
# *     0+    0                       2.72871e+07   1.73596e+07            36.38%
#       0     0   2.72778e+07     3   2.72871e+07   2.72778e+07        9    0.03%
#       0     0        cutoff         2.72871e+07                     10    0.00%
# Elapsed time = 0.88 sec. (419.37 ticks, tree = 0.01 MB, solutions = 2)
#
# Root node processing (before b&c):
#   Real time             =    0.89 sec. (422.99 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.89 sec. (422.99 ticks)
#
# Solution pool: 2 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  2.7287127391e+07
# Solution time =    0.89 sec.  Iterations = 10  Nodes = 0
# Deterministic time = 423.28 ticks  (475.60 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmp6rk3fpli.cplex.sol'.
# CPLEX>

# %%
model_writer.backconfigure_network()

# %%
model_writer.net.sgen
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 684    8   0.0     0.0     NaN      1.0       False  wye
# 1  PV 633    2   0.0     0.0     NaN      1.0       False  wye
# 2  PV 646    4   0.0     0.0     NaN      1.0        True  wye
# 3  WT 633    2   0.0     0.0     NaN      1.0       False  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  0.000000    0.000000  Resource: PV 684
# 1            True  0.000000    0.000000  Resource: PV 633
# 2            True  5.302287    2.651143  Resource: PV 646
# 3            True  0.000000    0.000000  Resource: WT 633

# %%
Resultados = model_writer.get_scenes_results()

# %%
Resultados
# Out:
#       SET_p_mw  645_p_mw  646_p_mw  633_p_mw  675_p_mw  611_p_mw  652_p_mw  \
# 0     2.322764 -0.674143 -0.823506 -0.173875 -0.220209 -0.208597 -0.222434
# 1     1.929609 -0.627122 -0.787896 -0.140952 -0.184316 -0.090045 -0.099278
# 2     1.847957 -0.674307 -0.776600 -0.134481 -0.141891 -0.056046 -0.064631
# 3     1.893291 -0.650220 -0.818748 -0.125901 -0.159627 -0.067184 -0.071611
# 4     1.870465 -0.641876 -0.836045 -0.119829 -0.133828 -0.065900 -0.072986
# ...        ...       ...       ...       ...       ...       ...       ...
# 5755  4.409518 -0.957437 -1.214890 -0.627962 -0.785792 -0.366176 -0.457262
# 5756  4.409669 -0.974709 -1.209995 -0.623788 -0.599564 -0.444670 -0.556943
# 5757  4.141414 -0.889929 -1.171872 -0.548028 -0.636375 -0.380727 -0.514483
# 5758  3.503768 -0.795651 -0.997251 -0.374338 -0.424991 -0.427983 -0.483554
# 5759  3.012644 -0.695640 -0.913267 -0.313012 -0.392922 -0.316198 -0.381605
#
#       PV 646_p_mw  L 650_632_pf_mw  L 632_671_pf_mw  L 671_684_pf_mw  \
# 0             0.0        -2.322764        -0.651240        -0.431031
# 1             0.0        -1.929609        -0.373640        -0.189323
# 2             0.0        -1.847957        -0.262569        -0.120677
# 3             0.0        -1.893291        -0.298421        -0.138795
# 4             0.0        -1.870465        -0.272714        -0.138886
# ...           ...              ...              ...              ...
# 5755          0.0        -4.409518        -1.609229        -0.823437
# 5756          0.0        -4.409669        -1.601176        -1.001613
# 5757          0.0        -4.141414        -1.531585        -0.895209
# 5758          0.0        -3.503768        -1.336528        -0.911537
# 5759          0.0        -3.012644        -1.090725        -0.697803
#
#       L 632_645_pf_mw  L 645_646_pf_mw  L 632_633_pf_mw  L 671_675_pf_mw  \
# 0           -1.497649        -0.823506        -0.173875        -0.220209
# 1           -1.415018        -0.787896        -0.140952        -0.184316
# 2           -1.450908        -0.776600        -0.134481        -0.141891
# 3           -1.468968        -0.818748        -0.125901        -0.159627
# 4           -1.477921        -0.836045        -0.119829        -0.133828
# ...               ...              ...              ...              ...
# 5755        -2.172327        -1.214890        -0.627962        -0.785792
# 5756        -2.184704        -1.209995        -0.623788        -0.599564
# 5757        -2.061801        -1.171872        -0.548028        -0.636375
# 5758        -1.792902        -0.997251        -0.374338        -0.424991
# 5759        -1.608907        -0.913267        -0.313012        -0.392922
#
#       L 684_611_pf_mw  L 684_652_pf_mw
# 0           -0.208597        -0.222434
# 1           -0.090045        -0.099278
# 2           -0.056046        -0.064631
# 3           -0.067184        -0.071611
# 4           -0.065900        -0.072986
# ...               ...              ...
# 5755        -0.366176        -0.457262
# 5756        -0.444670        -0.556943
# 5757        -0.380727        -0.514483
# 5758        -0.427983        -0.483554
# 5759        -0.316198        -0.381605
#
# [5760 rows x 17 columns]

# %%
lcoe = model_writer.lcoe()

# %%
tde = model_writer.total_discounted_energy()

# %%
ic = pe.value(model_writer.initial_cost_expression())

# %%
oc_e = model_writer.opetaring_costs_value(ext_elements)
oc_e
# Out:
# 21521634.082622755

# %%
oc_der = model_writer.opetaring_costs_value(der_elements)
oc_der
# Out:
# 744832.3697669352

# %%
eco_res['PV Only'] = [lcoe, tde, ic/tde, oc_e/tde, oc_der/tde]
eco_res
# Out:
# {'No DER': [108.7257451278002, 278080.4018373411, 0.0, 108.7257451278002, 0.0],
#  'PV Only': [98.12675474626243,
#   278080.4018373411,
#   18.054709736006817,
#   77.39356653839816,
#   2.678478471857983]}

# %%
plot_results(Resultados, a = 0, b = 360, elements = True, lines = False, l_ep = False)

# %% [markdown]
# # LCOE with PV and ST

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Additional Constraints
#
# 1) One PV plant
# 2) One Storage

# %%
model_writer.remove_if_has_constraint("no_ST")
# Out:
# True

# %%
model_writer.additional_constraint("one_ST", net.storage['model'][0].create + net.storage['model'][1].create <= 1)

# %% [markdown]
# ## Resolution

# %%
opt = pe.SolverFactory('cplex')
result_obj= opt.solve(model, tee=True)
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmptv2t6999.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmp7w3onn1b.pyomo.lp' read.
# Read time = 0.31 sec. (12.95 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmp7w3onn1b.pyomo.lp
# Objective sense      : Minimize
# Variables            :  103696  [Nneg: 34569,  Box: 57600,  Free: 11520,
#                                  Binary: 6,  General Integer: 1]
# Objective nonzeros   :   11534
# Linear constraints   :  138253  [Less: 69130,  Equal: 69123]
#   Nonzeros           :  307256
#   RHS nonzeros       :   34563
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 74.60052         Max   : 1085474.
# Linear constraints   :
#   Nonzeros           : Min   : 2.768879e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.05306375       Max   : 1.566390
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 48976 rows and 48966 columns.
# MIP Presolve modified 720 coefficients.
# Aggregator did 16322 substitutions.
# Reduced MIP has 72955 rows, 38408 columns, and 170387 nonzeros.
# Reduced MIP has 5 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.33 sec. (170.07 ticks)
# Found incumbent of value 3.0234499e+07 after 0.47 sec. (241.56 ticks)
# Probing fixed 0 vars, tightened 20784 bounds.
# Probing time = 0.58 sec. (434.94 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 3 coefficients.
# Reduced MIP has 72955 rows, 38408 columns, and 170387 nonzeros.
# Reduced MIP has 5 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.16 sec. (88.62 ticks)
# Probing fixed 0 vars, tightened 2506 bounds.
# Probing time = 0.06 sec. (21.96 ticks)
# Clique table members: 2.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 9.28 sec. (2820.93 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.02345e+07    10347.4417            99.97%
#       0     0   2.72772e+07     1   3.02345e+07   2.72772e+07       53    9.78%
# *     0+    0                       2.72871e+07   2.72772e+07             0.04%
#       0     0        cutoff         2.72871e+07   2.72871e+07     1865    0.00%
# Elapsed time = 13.25 sec. (5140.43 ticks, tree = 0.01 MB, solutions = 2)
#
# Clique cuts applied:  1
# Implied bound cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =   13.27 sec. (5144.78 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =   13.27 sec. (5144.78 ticks)
#
# Solution pool: 2 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  2.7287127391e+07
# Solution time =   13.27 sec.  Iterations = 1865  Nodes = 0
# Deterministic time = 5145.07 ticks  (387.84 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpk_xirzfw.cplex.sol'.
# CPLEX>

# %%
model_writer.backconfigure_network()

# %%
model_writer.net.sgen
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 684    8   0.0     0.0     NaN      1.0        True  wye
# 1  PV 633    2   0.0     0.0     NaN      1.0       False  wye
# 2  PV 646    4   0.0     0.0     NaN      1.0       False  wye
# 3  WT 633    2   0.0     0.0     NaN      1.0       False  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  5.302287    2.651143  Resource: PV 684
# 1            True  0.000000    0.000000  Resource: PV 633
# 2            True  0.000000    0.000000  Resource: PV 646
# 3            True  0.000000    0.000000  Resource: WT 633

# %%
model_writer.net.storage
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  soc_percent  min_e_mwh  max_e_mwh  \
# 0  ST 684    8   0.0     0.0     NaN          NaN        0.0        0.0
# 1  ST 632    1   0.0     0.0     NaN          NaN        0.0        0.0
#
#    scaling  in_service  type  max_p_mw  max_q_mvar             model
# 0      1.0       False  None       0.0         0.0  Resource: ST 684
# 1      1.0       False  None       0.0         0.0  Resource: ST 632

# %%
Resultados = model_writer.get_scenes_results()

# %%
Resultados
# Out:
#       SET_p_mw  645_p_mw  646_p_mw  633_p_mw  675_p_mw  611_p_mw  652_p_mw  \
# 0     2.322764 -0.674143 -0.823506 -0.173875 -0.220209 -0.208597 -0.222434
# 1     1.929609 -0.627122 -0.787896 -0.140952 -0.184316 -0.090045 -0.099278
# 2     1.847957 -0.674307 -0.776600 -0.134481 -0.141891 -0.056046 -0.064631
# 3     1.893291 -0.650220 -0.818748 -0.125901 -0.159627 -0.067184 -0.071611
# 4     1.870465 -0.641876 -0.836045 -0.119829 -0.133828 -0.065900 -0.072986
# ...        ...       ...       ...       ...       ...       ...       ...
# 5755  4.409518 -0.957437 -1.214890 -0.627962 -0.785792 -0.366176 -0.457262
# 5756  4.409669 -0.974709 -1.209995 -0.623788 -0.599564 -0.444670 -0.556943
# 5757  4.141414 -0.889929 -1.171872 -0.548028 -0.636375 -0.380727 -0.514483
# 5758  3.503768 -0.795651 -0.997251 -0.374338 -0.424991 -0.427983 -0.483554
# 5759  3.012644 -0.695640 -0.913267 -0.313012 -0.392922 -0.316198 -0.381605
#
#       PV 684_p_mw  L 650_632_pf_mw  L 632_671_pf_mw  L 671_684_pf_mw  \
# 0             0.0        -2.322764        -0.651240        -0.431031
# 1             0.0        -1.929609        -0.373640        -0.189323
# 2             0.0        -1.847957        -0.262569        -0.120677
# 3             0.0        -1.893291        -0.298421        -0.138795
# 4             0.0        -1.870465        -0.272714        -0.138886
# ...           ...              ...              ...              ...
# 5755          0.0        -4.409518        -1.609229        -0.823437
# 5756          0.0        -4.409669        -1.601176        -1.001613
# 5757          0.0        -4.141414        -1.531585        -0.895209
# 5758          0.0        -3.503768        -1.336528        -0.911537
# 5759          0.0        -3.012644        -1.090725        -0.697803
#
#       L 632_645_pf_mw  L 645_646_pf_mw  L 632_633_pf_mw  L 671_675_pf_mw  \
# 0           -1.497649        -0.823506        -0.173875        -0.220209
# 1           -1.415018        -0.787896        -0.140952        -0.184316
# 2           -1.450908        -0.776600        -0.134481        -0.141891
# 3           -1.468968        -0.818748        -0.125901        -0.159627
# 4           -1.477921        -0.836045        -0.119829        -0.133828
# ...               ...              ...              ...              ...
# 5755        -2.172327        -1.214890        -0.627962        -0.785792
# 5756        -2.184704        -1.209995        -0.623788        -0.599564
# 5757        -2.061801        -1.171872        -0.548028        -0.636375
# 5758        -1.792902        -0.997251        -0.374338        -0.424991
# 5759        -1.608907        -0.913267        -0.313012        -0.392922
#
#       L 684_611_pf_mw  L 684_652_pf_mw
# 0           -0.208597        -0.222434
# 1           -0.090045        -0.099278
# 2           -0.056046        -0.064631
# 3           -0.067184        -0.071611
# 4           -0.065900        -0.072986
# ...               ...              ...
# 5755        -0.366176        -0.457262
# 5756        -0.444670        -0.556943
# 5757        -0.380727        -0.514483
# 5758        -0.427983        -0.483554
# 5759        -0.316198        -0.381605
#
# [5760 rows x 17 columns]

# %%
lcoe = model_writer.lcoe()

# %%
tde = model_writer.total_discounted_energy()

# %%
ic = pe.value(model_writer.initial_cost_expression())

# %%
oc_e = model_writer.opetaring_costs_value(ext_elements)
oc_e
# Out:
# 21521634.082622793

# %%
oc_der = model_writer.opetaring_costs_value(der_elements)
oc_der
# Out:
# 744832.3697669352

# %%
eco_res['PV + ST'] = [lcoe, tde, ic/tde, oc_e/tde, oc_der/tde]
eco_res
# Out:
# {'No DER': [108.7257451278002, 278080.4018373411, 0.0, 108.7257451278002, 0.0],
#  'PV Only': [98.12675474626243,
#   278080.4018373411,
#   18.054709736006817,
#   77.39356653839816,
#   2.678478471857983],
#  'PV + ST': [98.12675474626259,
#   278080.4018373411,
#   18.05470973600683,
#   77.39356653839829,
#   2.678478471857983]}

# %%
plot_results(Resultados, a = 0, b = 360, elements = True, lines = False, l_ep = False)

# %% [markdown]
# # LCOE with WT

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Additional Constraints
#
# 1) No PV plant
# 2) No Storage
# 3) One WTG site

# %%
model_writer.remove_if_has_constraint("no_WT")
model_writer.remove_if_has_constraint("one_PV")
model_writer.remove_if_has_constraint("one_ST")
# Out:
# True

# %%
model_writer.additional_constraint("no_PV", net.sgen['model'][0].create + net.sgen['model'][1].create + net.sgen['model'][2].create == 0)
model_writer.additional_constraint("no_ST", net.storage['model'][0].create + net.storage['model'][1].create  == 0)

# %% [markdown]
# ## Resolution

# %%
opt = pe.SolverFactory('cplex')
result_obj= opt.solve(model, tee=True)
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmpqxkszi26.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmpl3u6wm8x.pyomo.lp' read.
# Read time = 0.28 sec. (12.94 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmpl3u6wm8x.pyomo.lp
# Objective sense      : Minimize
# Variables            :  103696  [Nneg: 34569,  Box: 57600,  Free: 11520,
#                                  Binary: 6,  General Integer: 1]
# Objective nonzeros   :   11534
# Linear constraints   :  138252  [Less: 69128,  Equal: 69124]
#   Nonzeros           :  307255
#   RHS nonzeros       :   34561
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 74.60052         Max   : 1085474.
# Linear constraints   :
#   Nonzeros           : Min   : 2.768879e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.05306375       Max   : 1.566390
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 132748 rows and 98191 columns.
# MIP Presolve modified 720 coefficients.
# Aggregator did 1 substitutions.
# Reduced MIP has 5503 rows, 5504 columns, and 11006 nonzeros.
# Reduced MIP has 1 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.23 sec. (135.09 ticks)
# Found incumbent of value 3.0234499e+07 after 0.28 sec. (159.38 ticks)
# Probing time = 0.00 sec. (0.55 ticks)
# Tried aggregator 1 time.
# MIP Presolve modified 1 coefficients.
# Reduced MIP has 5503 rows, 5504 columns, and 11006 nonzeros.
# Reduced MIP has 1 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (5.69 ticks)
# Probing time = 0.00 sec. (0.43 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.14 sec. (131.19 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.02345e+07  5458422.9520            81.95%
# *     0+    0                       2.52886e+07  5458422.9520            78.42%
#       0     0   2.52676e+07     2   2.52886e+07   2.52676e+07       11    0.08%
#       0     0        cutoff         2.52886e+07   2.52886e+07      218    0.00%
# Elapsed time = 0.63 sec. (375.51 ticks, tree = 0.01 MB, solutions = 2)
#
# Mixed integer rounding cuts applied:  210
#
# Root node processing (before b&c):
#   Real time             =    0.66 sec. (379.06 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.66 sec. (379.06 ticks)
#
# Solution pool: 2 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  2.5288617558e+07
# Solution time =    0.67 sec.  Iterations = 218  Nodes = 0
# Deterministic time = 379.35 ticks  (564.51 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmptef0kig5.cplex.sol'.
# CPLEX>

# %%
model_writer.backconfigure_network()

# %%
model_writer.net.sgen
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 684    8   0.0     0.0     NaN      1.0       False  wye
# 1  PV 633    2   0.0     0.0     NaN      1.0       False  wye
# 2  PV 646    4   0.0     0.0     NaN      1.0       False  wye
# 3  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True       0.0         0.0  Resource: PV 684
# 1            True       0.0         0.0  Resource: PV 633
# 2            True       0.0         0.0  Resource: PV 646
# 3            True       7.2         3.6  Resource: WT 633

# %%
model_writer.net.storage
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  soc_percent  min_e_mwh  max_e_mwh  \
# 0  ST 684    8   0.0     0.0     NaN          NaN        0.0        0.0
# 1  ST 632    1   0.0     0.0     NaN          NaN        0.0        0.0
#
#    scaling  in_service  type  max_p_mw  max_q_mvar             model
# 0      1.0       False  None       0.0         0.0  Resource: ST 684
# 1      1.0       False  None       0.0         0.0  Resource: ST 632

# %%
lcoe = model_writer.lcoe()

# %%
tde = model_writer.total_discounted_energy()

# %%
ic = pe.value(model_writer.initial_cost_expression())

# %%
oc_e = model_writer.opetaring_costs_value(ext_elements)
oc_e
# Out:
# 15666647.39606379

# %%
oc_der = model_writer.opetaring_costs_value(der_elements)
oc_der
# Out:
# 2051970.1623798045

# %%
eco_res['WT Only'] = [lcoe, tde, ic/tde, oc_e/tde, oc_der/tde]
eco_res
# Out:
# {'No DER': [108.7257451278002, 278080.4018373411, 0.0, 108.7257451278002, 0.0],
#  'PV Only': [98.12675474626243,
#   278080.4018373411,
#   18.054709736006817,
#   77.39356653839816,
#   2.678478471857983],
#  'PV + ST': [98.12675474626259,
#   278080.4018373411,
#   18.05470973600683,
#   77.39356653839829,
#   2.678478471857983],
#  'WT Only': [90.93994899085241,
#   278080.4018373411,
#   27.222342710896818,
#   56.33855278024144,
#   7.379053499714351]}

# %%
Resultados = model_writer.get_scenes_results()

# %%
Resultados
# Out:
#       SET_p_mw  645_p_mw  646_p_mw  633_p_mw  675_p_mw  611_p_mw  652_p_mw  \
# 0     2.322764 -0.674143 -0.823506 -0.173875 -0.220209 -0.208597 -0.222434
# 1     1.929609 -0.627122 -0.787896 -0.140952 -0.184316 -0.090045 -0.099278
# 2     1.847957 -0.674307 -0.776600 -0.134481 -0.141891 -0.056046 -0.064631
# 3     1.893291 -0.650220 -0.818748 -0.125901 -0.159627 -0.067184 -0.071611
# 4     1.869824 -0.641876 -0.836045 -0.119829 -0.133828 -0.065900 -0.072986
# ...        ...       ...       ...       ...       ...       ...       ...
# 5755  2.737688 -0.957437 -1.214890 -0.627962 -0.785792 -0.366176 -0.457262
# 5756  1.847852 -0.974709 -1.209995 -0.623788 -0.599564 -0.444670 -0.556943
# 5757  1.659970 -0.889929 -1.171872 -0.548028 -0.636375 -0.380727 -0.514483
# 5758  2.237182 -0.795651 -0.997251 -0.374338 -0.424991 -0.427983 -0.483554
# 5759  2.465660 -0.695640 -0.913267 -0.313012 -0.392922 -0.316198 -0.381605
#
#       WT 633_p_mw  L 650_632_pf_mw  L 632_671_pf_mw  L 671_684_pf_mw  \
# 0        0.000000        -2.322764        -0.651240        -0.431031
# 1        0.000000        -1.929609        -0.373640        -0.189323
# 2        0.000000        -1.847957        -0.262569        -0.120677
# 3        0.000000        -1.893291        -0.298421        -0.138795
# 4        0.000641        -1.869824        -0.272714        -0.138886
# ...           ...              ...              ...              ...
# 5755     1.671830        -2.737688        -1.609229        -0.823437
# 5756     2.561816        -1.847852        -1.601176        -1.001613
# 5757     2.481444        -1.659970        -1.531585        -0.895209
# 5758     1.266586        -2.237182        -1.336528        -0.911537
# 5759     0.546984        -2.465660        -1.090725        -0.697803
#
#       L 632_645_pf_mw  L 645_646_pf_mw  L 632_633_pf_mw  L 671_675_pf_mw  \
# 0           -1.497649        -0.823506        -0.173875        -0.220209
# 1           -1.415018        -0.787896        -0.140952        -0.184316
# 2           -1.450908        -0.776600        -0.134481        -0.141891
# 3           -1.468968        -0.818748        -0.125901        -0.159627
# 4           -1.477921        -0.836045        -0.119188        -0.133828
# ...               ...              ...              ...              ...
# 5755        -2.172327        -1.214890         1.043869        -0.785792
# 5756        -2.184704        -1.209995         1.938028        -0.599564
# 5757        -2.061801        -1.171872         1.933415        -0.636375
# 5758        -1.792902        -0.997251         0.892248        -0.424991
# 5759        -1.608907        -0.913267         0.233972        -0.392922
#
#       L 684_611_pf_mw  L 684_652_pf_mw
# 0           -0.208597        -0.222434
# 1           -0.090045        -0.099278
# 2           -0.056046        -0.064631
# 3           -0.067184        -0.071611
# 4           -0.065900        -0.072986
# ...               ...              ...
# 5755        -0.366176        -0.457262
# 5756        -0.444670        -0.556943
# 5757        -0.380727        -0.514483
# 5758        -0.427983        -0.483554
# 5759        -0.316198        -0.381605
#
# [5760 rows x 17 columns]

# %%
plot_results(Resultados, a = 0, b = 360, elements = True, lines = False, l_ep = False)

# %%
plot_results(Resultados, a = 0, b = 120, elements = True, lines = False, l_ep = False)

# %% [markdown]
# # LCOE with PV, WT and ST

# %% [markdown]
# ## Model Creation

# %% [markdown]
# ### Additional Constraints
#
# 1) One PV plant
# 2) One Storage
# 3) One WTG site

# %%
model_writer.remove_if_has_constraint("no_ST")
model_writer.remove_if_has_constraint("no_PV")
model_writer.remove_if_has_constraint("no_WT")
# Out:
# False

# %%
model_writer.additional_constraint("one_PV", net.sgen['model'][0].create + net.sgen['model'][1].create + net.sgen['model'][2].create <= 1)
model_writer.additional_constraint("one_ST", net.storage['model'][0].create + net.storage['model'][1].create <= 1)

# %% [markdown]
# ## Resolution

# %%
opt = pe.SolverFactory('cplex')
result_obj= opt.solve(model, tee=True)
# Out:
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\jmsar\AppData\Local\Temp\tmpv_r3txn0.cplex.log' open.
# CPLEX> Problem 'C:\Users\jmsar\AppData\Local\Temp\tmpzyl7a1ql.pyomo.lp' read.
# Read time = 0.31 sec. (12.99 ticks)
# CPLEX> Problem name         : C:\Users\jmsar\AppData\Local\Temp\tmpzyl7a1ql.pyomo.lp
# Objective sense      : Minimize
# Variables            :  103696  [Nneg: 34569,  Box: 57600,  Free: 11520,
#                                  Binary: 6,  General Integer: 1]
# Objective nonzeros   :   11534
# Linear constraints   :  138252  [Less: 69130,  Equal: 69122]
#   Nonzeros           :  307255
#   RHS nonzeros       :   34563
#
# Variables            : Min LB: -8.230705        Max UB: 10.00000
# Objective nonzeros   : Min   : 74.60052         Max   : 1085474.
# Linear constraints   :
#   Nonzeros           : Min   : 2.768879e-17     Max   : 1000.000
#   RHS nonzeros       : Min   : 0.05306375       Max   : 1.566390
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# Tried aggregator 2 times.
# MIP Presolve eliminated 40170 rows and 40160 columns.
# MIP Presolve modified 720 coefficients.
# Aggregator did 17264 substitutions.
# Reduced MIP has 80818 rows, 46272 columns, and 191668 nonzeros.
# Reduced MIP has 6 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.39 sec. (196.16 ticks)
# Found incumbent of value 3.0234499e+07 after 0.55 sec. (274.16 ticks)
# Probing fixed 0 vars, tightened 15247 bounds.
# Probing time = 0.33 sec. (240.61 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve modified 3 coefficients.
# Reduced MIP has 80818 rows, 46272 columns, and 191668 nonzeros.
# Reduced MIP has 6 binaries, 1 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.22 sec. (99.80 ticks)
# Probing fixed 0 vars, tightened 2474 bounds.
# Probing time = 0.09 sec. (24.31 ticks)
# Clique table members: 2.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 11.45 sec. (4554.28 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                       3.02345e+07    10347.4417            99.97%
#       0     0   2.43998e+07     3   3.02345e+07   2.43998e+07      107   19.30%
# *     0+    0                       2.50097e+07   2.43998e+07             2.44%
# *     0+    0                       2.44247e+07   2.43998e+07             0.10%
#       0     0        cutoff         2.44247e+07   2.44247e+07      147    0.00%
# Elapsed time = 18.94 sec. (7173.39 ticks, tree = 0.01 MB, solutions = 3)
#
# Implied bound cuts applied:  2699
# Mixed integer rounding cuts applied:  7300
# Gomory fractional cuts applied:  1
#
# Root node processing (before b&c):
#   Real time             =   18.95 sec. (7178.71 ticks)
# Parallel b&c, 4 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =   18.95 sec. (7178.71 ticks)
#
# Solution pool: 3 solutions saved.
#
# MIP - Integer optimal solution:  Objective =  2.4424662628e+07
# Solution time =   18.95 sec.  Iterations = 147  Nodes = 0
# Deterministic time = 7179.01 ticks  (378.78 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\jmsar\AppData\Local\Temp\tmpkoina9rv.cplex.sol'.
# CPLEX>

# %%
model_writer.backconfigure_network()

# %%
model_writer.net.sgen
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  scaling  in_service type  \
# 0  PV 684    8   0.0     0.0     NaN      1.0       False  wye
# 1  PV 633    2   0.0     0.0     NaN      1.0        True  wye
# 2  PV 646    4   0.0     0.0     NaN      1.0       False  wye
# 3  WT 633    2   0.0     0.0     NaN      1.0        True  wye
#
#    current_source  max_p_mw  max_q_mvar             model
# 0            True  0.000000    0.000000  Resource: PV 684
# 1            True  3.485932    1.742966  Resource: PV 633
# 2            True  0.000000    0.000000  Resource: PV 646
# 3            True  5.600000    2.800000  Resource: WT 633

# %%
model_writer.net.storage
# Out:
#      name  bus  p_mw  q_mvar  sn_mva  soc_percent  min_e_mwh  max_e_mwh  \
# 0  ST 684    8   0.0     0.0     NaN          NaN        0.0        0.0
# 1  ST 632    1   0.0     0.0     NaN          NaN        0.0        0.0
#
#    scaling  in_service  type  max_p_mw  max_q_mvar             model
# 0      1.0       False  None       0.0         0.0  Resource: ST 684
# 1      1.0       False  None       0.0         0.0  Resource: ST 632

# %%
lcoe = model_writer.lcoe()

# %%
tde = model_writer.total_discounted_energy()

# %%
ic = pe.value(model_writer.initial_cost_expression())

# %%
oc_e = model_writer.opetaring_costs_value(ext_elements)
oc_e
# Out:
# 13209864.963375263

# %%
oc_der = model_writer.opetaring_costs_value(der_elements)
oc_der
# Out:
# 2020591.9956303805

# %%
eco_res['WT + PV'] = [lcoe, tde, ic/tde, oc_e/tde, oc_der/tde]
eco_res
# Out:
# {'No DER': [108.7257451278002, 278080.4018373411, 0.0, 108.7257451278002, 0.0],
#  'PV Only': [98.12675474626243,
#   278080.4018373411,
#   18.054709736006817,
#   77.39356653839816,
#   2.678478471857983],
#  'PV + ST': [98.12675474626259,
#   278080.4018373411,
#   18.05470973600683,
#   77.39356653839829,
#   2.678478471857983],
#  'WT Only': [90.93994899085241,
#   278080.4018373411,
#   27.222342710896818,
#   56.33855278024144,
#   7.379053499714351],
#  'WT + PV': [87.83309599334376,
#   278080.4018373411,
#   33.06311990594366,
#   47.50376105649536,
#   7.266215030904246]}

# %%
Resultados = model_writer.get_scenes_results()

# %%
Resultados
# Out:
#       SET_p_mw  645_p_mw  646_p_mw  633_p_mw  675_p_mw  611_p_mw  652_p_mw  \
# 0     2.322764 -0.674143 -0.823506 -0.173875 -0.220209 -0.208597 -0.222434
# 1     1.929609 -0.627122 -0.787896 -0.140952 -0.184316 -0.090045 -0.099278
# 2     1.847957 -0.674307 -0.776600 -0.134481 -0.141891 -0.056046 -0.064631
# 3     1.893291 -0.650220 -0.818748 -0.125901 -0.159627 -0.067184 -0.071611
# 4     1.869967 -0.641876 -0.836045 -0.119829 -0.133828 -0.065900 -0.072986
# ...        ...       ...       ...       ...       ...       ...       ...
# 5755  3.109206 -0.957437 -1.214890 -0.627962 -0.785792 -0.366176 -0.457262
# 5756  2.417145 -0.974709 -1.209995 -0.623788 -0.599564 -0.444670 -0.556943
# 5757  2.211402 -0.889929 -1.171872 -0.548028 -0.636375 -0.380727 -0.514483
# 5758  2.518646 -0.795651 -0.997251 -0.374338 -0.424991 -0.427983 -0.483554
# 5759  2.587212 -0.695640 -0.913267 -0.313012 -0.392922 -0.316198 -0.381605
#
#       PV 633_p_mw  WT 633_p_mw  L 650_632_pf_mw  L 632_671_pf_mw  \
# 0             0.0     0.000000        -2.322764        -0.651240
# 1             0.0     0.000000        -1.929609        -0.373640
# 2             0.0     0.000000        -1.847957        -0.262569
# 3             0.0     0.000000        -1.893291        -0.298421
# 4             0.0     0.000498        -1.869967        -0.272714
# ...           ...          ...              ...              ...
# 5755          0.0     1.300313        -3.109206        -1.609229
# 5756          0.0     1.992524        -2.417145        -1.601176
# 5757          0.0     1.930012        -2.211402        -1.531585
# 5758          0.0     0.985122        -2.518646        -1.336528
# 5759          0.0     0.425432        -2.587212        -1.090725
#
#       L 671_684_pf_mw  L 632_645_pf_mw  L 645_646_pf_mw  L 632_633_pf_mw  \
# 0           -0.431031        -1.497649        -0.823506        -0.173875
# 1           -0.189323        -1.415018        -0.787896        -0.140952
# 2           -0.120677        -1.450908        -0.776600        -0.134481
# 3           -0.138795        -1.468968        -0.818748        -0.125901
# 4           -0.138886        -1.477921        -0.836045        -0.119331
# ...               ...              ...              ...              ...
# 5755        -0.823437        -2.172327        -1.214890         0.672351
# 5756        -1.001613        -2.184704        -1.209995         1.368736
# 5757        -0.895209        -2.061801        -1.171872         1.381984
# 5758        -0.911537        -1.792902        -0.997251         0.610785
# 5759        -0.697803        -1.608907        -0.913267         0.112420
#
#       L 671_675_pf_mw  L 684_611_pf_mw  L 684_652_pf_mw
# 0           -0.220209        -0.208597        -0.222434
# 1           -0.184316        -0.090045        -0.099278
# 2           -0.141891        -0.056046        -0.064631
# 3           -0.159627        -0.067184        -0.071611
# 4           -0.133828        -0.065900        -0.072986
# ...               ...              ...              ...
# 5755        -0.785792        -0.366176        -0.457262
# 5756        -0.599564        -0.444670        -0.556943
# 5757        -0.636375        -0.380727        -0.514483
# 5758        -0.424991        -0.427983        -0.483554
# 5759        -0.392922        -0.316198        -0.381605
#
# [5760 rows x 18 columns]

# %%
plot_results(Resultados, a = 0, b = 360, elements = True, lines = False, l_ep = False)

# %%
plot_results(Resultados, a = 0, b = 120, elements = True, lines = False, l_ep = False)

# %% [markdown]
# # Results

# %%
import numpy as np

# %%
import matplotlib.colors as mcolors

# %%
eco_res
# Out:
# {'No DER': [108.7257451278002, 278080.4018373411, 0.0, 108.7257451278002, 0.0],
#  'PV Only': [98.12675474626243,
#   278080.4018373411,
#   18.054709736006817,
#   77.39356653839816,
#   2.678478471857983],
#  'PV + ST': [98.12675474626259,
#   278080.4018373411,
#   18.05470973600683,
#   77.39356653839829,
#   2.678478471857983],
#  'WT Only': [90.93994899085241,
#   278080.4018373411,
#   27.222342710896818,
#   56.33855278024144,
#   7.379053499714351],
#  'WT + PV': [87.83309599334376,
#   278080.4018373411,
#   33.06311990594366,
#   47.50376105649536,
#   7.266215030904246]}

# %%
del eco_res['PV + ST']

# %%
columns = [k for k in eco_res.keys()]
columns
# Out:
# ['No DER', 'PV Only', 'WT Only', 'WT + PV']

# %%
rows = ['Initial Cost', 'External Energy', 'Operating Cost']

# %%
data = [eco_res[k][2:] for k in eco_res.keys()]

# %%
data
# Out:
# [[0.0, 108.7257451278002, 0.0],
#  [18.054709736006817, 77.39356653839816, 2.678478471857983],
#  [27.222342710896818, 56.33855278024144, 7.379053499714351],
#  [33.06311990594366, 47.50376105649536, 7.266215030904246]]

# %%
data[0]
# Out:
# [0.0, 108.7257451278002, 0.0]

# %%
fig, ax = plt.subplots(1, 1)

fig.set_size_inches(10,6)
    
values = np.arange(0, 2500, 500)
value_increment = 1000

# Get some pastel shades for the colors
colors = plt.cm.BuPu(np.linspace(0, 0.5, len(rows)))
colors = [color for name, color in mcolors.TABLEAU_COLORS.items()]
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

for col in range(len(columns)):
    y_offset = 0
    for d in range(len(data[col])):
        dat = data[col][d]
        plt.bar(0.5 + 1*col, dat, bar_width, bottom=y_offset, color =colors[d])
        y_offset += dat


# Adjust layout to make room for the table:
#plt.subplots_adjust(left=0.2, bottom=0.2)

plt.ylabel("LCOE in USD/MWh")
#plt.yticks(values * value_increment, ['%d' % val for val in values])
plt.xticks([0.5, 1.5, 2.5, 3.5, 5], columns + [''])
plt.title('LCOE by Energy Mix')

ax.legend(rows, loc = 'center right')

plt.show()
